# %%
import pandas as pd 
import re
from pprint import pprint
from enum import Enum

pd.options.display.max_rows = 800
columns = []
path = '/Users/jed/Downloads/일일보고/2022/10월/20221005/일일보고_20221005.xlsx'

df = pd.read_excel(path, sheet_name='일일업무')

date = df['Unnamed: 2'][7]
for i in range(4,19):
    df = df.drop(columns=['Unnamed: '+str(i)])
df = df.drop(columns=['  일일 업무보고서'])
df = df.rename(columns={'Unnamed: 1':'현장','Unnamed: 2':'이름','Unnamed: 3':'작업'})
# df['현장'][0] = '값입력'
# df = pd.concat([df,df],axis = 1)
# df.to_excel('./test.xlsx',sheet_name="sdf")

columns_name ='현장'
df_names = df.drop(columns = [columns_name])
##이름에 가끔 빈칸이 있는 애들이 있어서 시트마다 이름을 불러올 필요성이 있다. 
df_names = df_names.dropna()
## Dropna를 진행하면 index가 순차 배열이 아니기에 다시 reset
df_names = df_names.reset_index()

names = []
# rest_index를 해야 0부터 접근가능.. 
for i in range(0,30):
    name = df_names.loc[i]
    text = name.values[1]
    if len(name['이름']) == 3 or len(name['이름'])==2 or len(name['이름'])==4:
        names.append(name['이름'])

works = dict()

# for name in names:

for name in names:
    works_parse_day = []
    works_parse_night = []
    works_etc = []
    row = df[df['이름']==name]
    name_value = row['이름']
    work_value = row['작업']
    works[name_value.values[0]] = work_value.values[0]
    ## works dict를 만들 필요는 없다. 바로 분석한다. 
    jugan_li = works[name]
    li = jugan_li.split(' ')
    for i in range(len(li)):
        if li[i].find('\n야근') != -1:
            index = li[i].find('야근')
            back = li[i][index:index+2]
            li[i] = li[i][:index-1]
            li.insert(i+1, back)

    class workers(Enum):
        designer = 1
        CAD = 2
        manager = 3

    DAY_TAT = {'day':1,'mid_night':0.25,'night':0.5} ## TAT
    ## 호기+WORKS_DIV 호기,호기 + WORKS_DIV 도면작업 시작은 작업자 구분에서 이미 갈림.
    WORKS_DIV = ['신규','업데이트']
    WORKS_DIV_A = ['설계','도면작업','업데이트','연차'] ## 이게 호기로 두개면 0.5, mid/2, night/2
    ## REV면 업데이트로 분류
    WORKS_DIV_B = ['협의','Tray','이슈대응','MAIN','SCR','이슈','REV']
    WORKS_DIV_C = ['GAS','EXHAUST', 'TOXIC','MAIN','PCW'] ## 도면 작업
    WORKS_DIV_D = ['사무업무','기타작업','정리','정산','본사'] ## 기타 업무

    """
        기존 DB를 지우지 말고 다른 Table을 만들어서 분류하는 작업 시작.
        분류 완료 되면 그래프를 그리거나, 엑셀과 연동하게 만들기. 웹에서 보면서 보고해보기.
    """
    """
        작업을 앞에 쓰고 뒤에 호기를 여러개 적는 경우. 메인 잡이 없는 경우는 서브 잡으로 작업을 분류하고 메인잡으로 다시 분류
        호기,호기 작업 작업
        REV -> 업데이트로 
        REV + 이슈 -> 업데이트로
        주야간에 몇 개의 호기를 했는지에 따라 TAT/개수
    """
    ## 주간 인덱스와 야근 인덱스를 먼저 구한다. 
    for j in range(len(li)):
        if li[j].find('주간') != -1:
            start = j
            print(j)
        if li[j].find('야근') != -1:
            end = j
            print(j)
        elif li[j].find('야간') != -1:
            end = j
            print(j)
    if end !='None':
    ## 주간 인덱스부터 야근 인덱스 전까지 탐색을 한다. 
        for k in range(start,end):
            if any(works in li[k] for works in WORKS_DIV_A):
                if li[k].find('설계') != -1: #<- WORKS_DIV
                    for j in range(end):
                        code = re.compile(f'\d+\w+\d').findall(li[j])
                        if len(code) == 1:
                            works_parse_day.append(name)
                            works_parse_day.append(li[k]) 
                            works_parse_day.append('1') 
                            works_parse_day.append(code)
                        elif len(code) == 2:
                            for h in range(2):
                                works_parse_day.append(name)
                                works_parse_day.append(li[k]) 
                                works_parse_day.append('0.5') 
                                works_parse_day.append(code[h])
                elif li[k].find('이슈') != -1 or li[i].find('협의') != -1:
                    for j in range(end):
                        code = re.compile(f'\d+\w+\d').findall(li[j])
                        if len(code) == 1:
                            works_parse_day.append(name)
                            works_parse_day.append(li[k]) 
                            works_parse_day.append('1')
                            works_parse_day.append(code)
                elif li[k].find('업데이트') != -1:
                    for j in range(end):
                        code = re.compile(f'\d+\w+\d').findall(li[j])
                        if len(code) == 1:
                            works_parse_day.append(name)
                            works_parse_day.append(li[k])
                            works_parse_day.append('1') 
                            works_parse_day.append(code)
                elif li[k].find('도면') != -1:
                    for j in range(end):
                        code = re.compile(f'\d+\w+\d').findall(li[j])
                        if len(code) == 1:
                            works_parse_day.append(name)
                            works_parse_day.append(li[k]) 
                            works_parse_day.append('1') 
                            works_parse_day.append(code)
            else:
                # code = re.compile(f'\d+\w+\d').findall(li[i])
                # if len(code) > 1:
                #     works_parse_night.append(name)
                #     works_parse_night.append('설계') 
                #     works_parse_night.append('1') 
                #     works_parse_night.append(code)
                works_etc.append(name)
                works_etc.append(li[k])  
        # 작업을 쓰지 않고 호기만 쓴 경우는 설계사일 경우는 설계 CAD인 경우는 설계로 간주한다.
        # for i in range(len(li)):
        #     code = re.compile(f'\d+\w+\d').findall(li)
        #     if len(code) == 1:
        #         works_parse_day.append(name)
        #         works_parse_day.append('dd')
        #         works_parse_day.append('1') 
        #         works_parse_day.append(code)
        ## 야근 인덱스부터 배열의 끝까지 탐색을 한다. 
        """
            위에서 한번 DB넣고 아래에서 한번 DB넣고 행 추가해서 아래를 넣으면 주간 야간 분리해서 들어가게 된다.
            단 야근 야간 분류해서 TAT를 구분하고 만약 '없음'이 있다면 PASS
        """
        for k in range(end,len(li)):
            if li[k].find('설계') != -1 or li[k].find('시작') != -1:
                for j in range(end):
                    code = re.compile(f'\d+\w+\d').findall(li[j])
                    if len(code) == 1:
                        works_parse_night.append(name)
                        works_parse_night.append(li[k]) ## DB넣기로 바꾸기..
                        works_parse_night.append('0.25') 
                        works_parse_night.append(code)
            elif li[k].find('이슈') != -1 or li[k].find('협의') != -1:
                for j in range(end):
                    code = re.compile(f'\d+\w+\d').findall(li[j])
                    if len(code) == 1:
                        works_parse_night.append(name)
                        works_parse_night.append(li[k])
                        works_parse_night.append('0.25') 
                        works_parse_night.append(code)
            elif li[k].find('업데이트') != -1:
                for j in range(end):
                    code = re.compile(f',+\d+\w+\d').findall(li[j])
                    if len(code) == 1:
                        works_parse_night.append(name)
                        works_parse_night.append(li[k])
                        works_parse_night.append('0.25') 
                        works_parse_night.append(code)
            else:
                # 작업을 쓰지 않고 호기만 쓴 경우는 설계사일 경우는 설계 CAD인 경우는 설계로 간주한다.
                code = re.compile(f'\d+\w+\d').findall(li[k])
                if len(code) > 1:
                    works_parse_night.append(name)
                    works_parse_night.append(li[k])
                    works_parse_night.append('0.25') 
                    works_parse_night.append(code)
                else:
                    works_etc.append(name)
                    works_etc.append(li[k]) 
        # 결과가 잘 나왔따.
        # 한 사람의 작업을 파악하고 데이터 베이스에 넣는다. 만약 값이 없다면 취소
        if len(works_parse_day) != 0:
            print(works_parse_day)
        if len(works_parse_night) != 0:
            print(works_parse_night) ## 날짜 빠짐... 여기서 데이터 프레임 플러스 + DB로 넣기(만약 작업 구분이 많아지면 그 만큼 행을 많이 만들어야 한다)
        # print(works_etc)
# ju = []
# yagun = []
# yagan = []

# for li in jugan_li:
#     if li.find('야근') != -1:
#         yagun.append(li)
#     elif li.find('야간') != -1:
#         yagan.append(li)
#     else:
#         ju.append(li)


# li = ['설계','이슈',',']
# ju_text =[name,'설계','주간']
# yagun_text =['야근']
# yagan_text =['야간']

# jugan = []
# yagun = []
# for i in range(len(jugan_li)):
#     li =jugan_li[i].split(' ')
#     for i in range(len(li)):
#         if li[i].find('주간') != -1:
#             for j in range(i,len(li)):
#                 jugan.append(li[j])
#         if li[i].find('야근') != -1:
#             for j in range(i,len(li)):
#                 yagun.append(li[j])

#         code = re.compile(f'\d+\w+\d').findall(text)
#         new_sul = re.compile(f'설계').findall(text)
#         print(code)
# for j in ju:
#     for i in range(3):
#         p = re.compile(f'\d+\w+\d+\s+{li[i]}')
#         ss= p.findall(j)
#         for s in ss:
#             ju_text.append(s)
        # text.appen d()

# for ya in yagun:
#     for i in range(3):
#         ss = re.compile(f'\d+\w+\d+\s+revit+\s+{li[i]}').findall(ya) ## 호기 + revit + 설계
#         for s in ss:
#             yagun_text.append(s)
# yagun_text
# ju_text
# print(ju_text + " " + yagun_text)
    ## 설계를 찾았으니 12번째부터 0번째까지 가져온다. 그리고 ,로 호기가 구분되어 있으면 그 앞까지 가져온다. 
    ## 리스트를 넘나들어야 하는데 이걸 하나로 묶어야겠다. 만약 이슈, 설계가 있으면 앞단과 묶는 작업이 필요하다. 일단 먼저 호기구분이 필요하다. 호기만 정확하게 가져와야 할 것. 
# ju_text + ya_text
# df.columns = columns['dl','이름','업무']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/jed/Desktop/개발/App/Socket/Untitled-1.ipynb 셀 2 in <cell line: 40>()
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=94'>95</a> if end !='None':
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=95'>96</a> ## 주간 인덱스부터 야근 인덱스 전까지 탐색을 한다.
# ---> <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=96'>97</a>     for k in range(start,end):
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=97'>98</a>         if any(works in li[k] for works in WORKS_DIV_A):
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=98'>99</a>             if li[k].find('설계') != -1: #<- WORKS_DIV
#
# /Users/jed/Desktop/개발/App/Socket/Untitled-1.ipynb 셀 2 in <genexpr>(.0)
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=94'>95</a> if end !='None':
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=95'>96</a> ## 주간 인덱스부터 야근 인덱스 전까지 탐색을 한다.
# ---> <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=96'>97</a>     for k in range(start,end):
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=97'>98</a>         if any(works in li[k] for works in WORKS_DIV_A):
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W1sZmlsZQ%3D%3D?line=98'>99</a>             if li[k].find('설계') != -1: #<- WORKS_DIV
#
# IndexError: list index out of range

# %%
import os 
import re
import pandas as pd 
import time 
from DBManager import DB_Manager

pd.options.display.max_columns = 400
pd.options.display.max_rows = 1200

table_name = 'M15_DAILY_WORKS'
db_manager = DB_Manager()
## 테이블을 초기화한다. 
db_manager.delete_rows(table_name)
# dir = 'D:/0. 보고/일일보고/2022/'
dir = '/Users/jed/Downloads/일일보고/2022/'
list = os.listdir(dir)
i=0
file_pathes = []
for i in range(1,12):
    try:
        dir_month = dir+str(i)+'월'
        list = os.listdir(dir_month)
        list.sort()
        for li in list:
            p = re.compile('[1-9]')
            res = p.findall(li)
            if len(res) > 0:
                #바로 파일일때 파일 리스트 만들기
                if li.endswith('xlsx') == True:
                    file_pathes.append(dir_month+"/"+li)
                #한 단계 폴더가 더 있을때 리스트 만들기(폴더 이름과 파일 이름 비교)
                else:
                    excel = os.listdir(dir_month+'/'+li)
                    for ex in excel:
                    ## 폴더안에 xlsx파일이 여러개 있으므로 날짜와 같은지 폴더이름과 파일이름을 비교한다. 20220105 == 일일보고_20220105.xlsx => [5:-5]
                        if ex.endswith('xlsx') and ex[5:-5]==li:
                            ## 바로 파일인 애들은 li(파일이름)을 붙이고
                            ## 일일마다 폴더가 있다면 날짜이름 폴더 + 파일이름
                            file_pathes.append(dir_month+"/"+li+"/"+ex)
        for file_path in file_pathes:          
            try:
                df = pd.read_excel(file_path, sheet_name='일일업무')
                date = li
                ## 필요없는 열을 지워준다.
                for i in range(4,11):
                    df = df.drop(columns=['Unnamed: '+str(i)])
                # 열 이름을 보기 좋게 바꾼다. 
                df = df.rename(columns={'  일일 업무보고서':'날짜','Unnamed: 1':'현장','Unnamed: 2':'이름','Unnamed: 3':'작업'})
                ## 한 열을 날짜로 채워준다. 
                df['날짜'] = df['날짜'].apply(lambda x:file_path[-13:-5]) 
                ## 이름만 추출 한다.
                names = df['이름'].drop_duplicates() 
                ## 정규식으로 이름만 추출한다. 
                for name in names.iteritems():
                    text = re.compile('[가-힣]').findall(str(name[1])) # 첫 번째 값은 행번호 두 번째가 이름임. Series이기 때문에 str형변환
                    if len(text) == 3 or len(text) == 2:
                        ## 정규식으로 이름을 걸러내고(text) 리스트로 사용하기 어려우니 바로 name과 작업내역을 데이터베이스에 넣는다.
                        daily_work = df[df['이름']== str(name[1])]
                        # print(str(name[1]) + " : " + str(daily_work))
                        daily_work = daily_work.drop(columns=['현장'])
                        ## 주간 데이터 한번 (daily_work는 데이터 프레임 2열 존재함. daily_work[''][1]이 내용임.
                        """
                            작업 내역 분할해서 데이터 베이스에 넣고 엑셀로 뽑으면 끝
                        """
                        ## 데이터를 분석해서 일별로 주간 호기 야간 호기 이슈대응, 교육 등을 분석해서 행을 늘린다. 
                        ## for문으로 진행해야할 것 같다. 
                        print(daily_work)
                        db_manager.excute_daily_work(table_name, daily_work['날짜'].to_list()[0], daily_work['이름'].to_list()[0], "nan", daily_work['작업'].to_list()[0],"nan","nan")
                        # db_manager.excute_daily_work(table_name, daily_work['날짜'].to_list()[0], daily_work['이름'].to_list()[0], "nan", daily_work['작업'].to_list()[0],"nan","nan")
                # works = pd.concat([works,df],axis = 1)
            except Exception as e:
                print(e)
    except Exception as e:
        print(e)
                #데이터 프레임으로 붙일려면 이렇게 작업을 하고 바로 데이터 베이스에 저장하기로 결정.
# Out:
#           날짜   이름                     작업
# 12  20220103  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220103  김남일
#
#                                                               작업
# 13  DDWorsk개선\n 1. 머터리얼 그룹 기능 구현(~1/4)\n 2. 유틸리티 연결 호환성 구현(~1/4)
#           날짜   이름  \
# 14  20220103  이형철
#
#                                                                  작업
# 14  DDWorks 분석\n 1. DDWorks 개발환경 세팅(완료)\n 2. DDWorks 테스트 및 분석(~1/7)
#           날짜   이름  \
# 15  20220103  김원철
#
#                                                                작업
# 15  DDWorks 개선\n 1. POC 기준 회전모드(완료)\n 2. 에러체크 삼각형 교차 함수 속도 개선(완료)
#           날짜   이름                                                    작업
# 16  20220103  엄정숙  2021년 12월 자금일보 마감(완료)\n법인카드사용내역 확인\n2022년 연차공지(~1/7)
#           날짜   이름  \
# 17  20220103  음종호
#
#                                                                                                                                                                           작업
# 17  DDWorksWebManager(Uams)\n 1. 브라우저 쿠키 문제로 빌드시 파일이름 hash 새롭게 부여하도록 추가(~1/3, 완료)\n 2. 빌드시 파일 경로 위치 잡도록 추가(~1/3, 완료)\nDDWorks\n 1. Visual Studio 2022 설치 및 개발환경 구성(~1/3, 완료)
#           날짜   이름  \
# 18  20220103  구은비
#
#                                                                                                                                                 작업
# 18  DDWorks 기능 개선\n 1. Selection List Export 기능 수정(~1/3 100%)\n 2. 그룹 머터리얼 UI 기능 개발(~1/4, 80%)\n 3. Utility Group - Utility 드래그 앤 드롭 이동(~1/4, 80%)
#           날짜   이름  \
# 19  20220103  김선홍
#
#                                                                                                                      작업
# 19  DDWorks 개선\n 1. 기준정보 전체 Export 기능(완료)\n 2. Utility-Utility Rule 기능 및 UI 개발 (80%, ~1/4)\n 3. 기준정보 전체 Import 기능(~1/7)
#           날짜  이름  \
# 20  20220103  강현
#
#                                                                                                                                작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-E1 수동정합성 검증 진행중\n  2) 12월 5주차 주간보고 작성 완료\n 2. BIM 업데이트\n  1) 2022-01-12 납품구역 BIM 업데이트 완료
#           날짜   이름  \
# 21  20220103  우제민
#
#                                                                                                                                작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-E1 수동정합성 검증 진행중\n  2) 12월 5주차 주간보고 작성 완료\n 2. BIM 업데이트\n  1) 2022-01-12 납품구역 BIM 업데이트 완료
#           날짜   이름                              작업
# 22  20220103  방태훈  주간-5TCW4107 설계\n야근-5TCW4107 설계
#           날짜   이름                     작업
# 23  20220103  오세광  주간-5TCT3905 설계\n야근-없음
#           날짜    이름                                    작업
# 24  20220103  김병훈   주간-5EV42001 설계, 이슈대응\n야근-5EV42001 설계
#           날짜   이름  작업
# 25  20220103  박정수  결근
#           날짜   이름                                  작업
# 26  20220103  윤태현  주간-5EV50110 업데이트\n야근-5EV50110 업데이트
#           날짜   이름                                  작업
# 27  20220103  김상우  주간-5ES33801 업데이트\n야근-5ES33801 업데이트
#           날짜   이름                                  작업
# 28  20220103  박선미  주간-5EV55901 도면작업\n야근-5EV55901 도면작업
#           날짜   이름                                            작업
# 29  20220103  한소연  주간-5TCW4107, 5TCT3905 도면작업\n야근-5EV50110 도면작업
#           날짜   이름                                            작업
# 30  20220103  최보연  주간-5TCW4107, 5ECD2801 도면작업\n야근-5EV50110 도면작업
#           날짜   이름                                            작업
# 31  20220103  심지현  주간-5ECD2801, 5TCW4107 도면작업\n야근-5TCW4107 도면작업
#           날짜    이름                           작업
# 32  20220103  최종혁   주간 - 현장 대응, 이슈처리\n야근 - 이슈처리
#           날짜   이름                                              작업
# 33  20220103  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름                                              작업
# 34  20220103  문진영   주간 - 6DSL2607 Revit 설계\n야근 - 6DSL2607 Revit 설계
#           날짜   이름                                              작업
# 35  20220103  김도일  주간 - 6IPP2508 Revit 설계\n야근 - 6IPP2508 Revit 설계
#           날짜   이름                                              작업
# 36  20220103  김범석  주간 - 6IRT2503 Revit 설계\n야근 - 6IRT2504 Revit 설계
#           날짜   이름                                       작업
# 37  20220103  한예지  주간 - 6DSA5918 도면작업 \n야근 - 6DBP5652 도면작업
#           날짜   이름                                                작업
# 38  20220103  연예은  주간 - 6DSP5410, 6DSL5802 도면작업\n야근 - 6DBP5652 도면작업
#           날짜   이름                                      작업
# 39  20220103  박수미  주간 - 6DSA5912 도면작업\n야근 - 6DSA5910 도면작업
#           날짜   이름                                          작업
# 40  20220103  홍지훈  주간 - 6DSA5910 SCR 설계\n야근 - 6DSA5910 SCR 설계
#           날짜    이름  \
# 41  20220103  이영섭
#
#                                                                   작업
# 41  주간 - 6DMT5645,5646,5647 SCR’ 설계\n야근 - 6DMT5645,5646,5647 SCR’ 설계
#           날짜   이름                                                          작업
# 42  20220103  배소연  주간 - 6DSA5733, 6DSP5409 도면작업\n야근 - 6DSP5409, 6DSP5410 도면작업
#           날짜   이름                                                          작업
# 43  20220103  한규현  주간 - 6DHQ5727, 6DFN5645 도면작업\n야근 - 6DFN5645, 6DSL5802 도면작업
#           날짜   이름  \
# 44  20220103  고필원
#
#                                                                 작업
# 44  주간 - 장비배치, 6IPP2508 revit 도면작업\n야근 - 장비배치, 6IPP2508 revit 도면작업
#           날짜   이름                     작업
# 12  20220104  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름                                                        작업
# 13  20220104  김남일  DDWorsk개선\n 1. 머터리얼 그룹 기능 구현(완료)\n 2. 유틸리티 연결 호환성 구현(완료)
#           날짜   이름  \
# 14  20220104  이형철
#
#                                                                                                                                작업
# 14  DDWorks 분석\n 1. DDWorks Model Designer 기능 분석(완료)\n 2. DDWorks Space Designer 기능 분석(완료)\n 3. DDWorks Hookup Designer 기능 분석(완료)
#           날짜   이름                                                 작업
# 15  20220104  김원철  DDWorks 개선\n1. 유틸리티-유틸리티 적용(완료)\n2. 그룹머터리얼 적용(완료)
#           날짜   이름                                       작업
# 16  20220104  엄정숙  법인등기 서류제출 완료(~1/12)\n급여작업\n1. 추가연장수당 반영
#           날짜   이름                                작업
# 17  20220104  음종호  DDWorks\n1. 코드 분석 및 메뉴얼 확인(~1/7)
#           날짜   이름  \
# 18  20220104  구은비
#
#                                                                                                                                          작업
# 18  DDWorks 기능 개선\n 1. 그룹 머터리얼 UI 기능 개발(~1/4, 100%)\n 2. Utility Group - Utility 드래그 앤 드롭 이동(~1/4, 100%)\n 3. 머터리얼 카테고리 UI 기능 개발(~1/5, 90%)
#           날짜   이름  \
# 19  20220104  김선홍
#
#                                                                                                   작업
# 19  DDWorks 개선\n 1. Utility-Utility Rule 기능 및 UI 개발 (완료)\n 2. 기준정보 전체 Import 기능(~1/7)\n삼성SDC 출장(1/5)
#           날짜  이름  \
# 20  20220104  강현
#
#                                                                               작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-E1 수동정합성 검증 완료\n  2) 4F-E1 수동정합성 검증 진행중
#           날짜   이름  \
# 21  20220104  우제민
#
#                                                                               작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-E1 수동정합성 검증 완료\n  2) 4F-E1 수동정합성 검증 진행중
#           날짜   이름                              작업
# 22  20220104  방태훈  주간-5TCW4107 설계\n야근-5TCW4108 설계
#           날짜   이름                              작업
# 23  20220104  오세광  주간-5TCT3905 설계\n야근-5TCT3905 설계
#           날짜    이름                                               작업
# 24  20220104  김병훈   주간-5EV42001, 5EV542002 설계, 이슈대응\n야근-5EHS4201 설계
#           날짜   이름  작업
# 25  20220104  박정수  결근
#           날짜   이름                                  작업
# 26  20220104  윤태현  주간-5EV50110 업데이트\n야근-5EV50110 업데이트
#           날짜   이름                       작업
# 27  20220104  김상우  주간-5ES33801 업데이트\n야근-없음
#           날짜   이름                                  작업
# 28  20220104  박선미  주간-5TCW4107 도면작업\n야근-5ES33707 도면작업
#           날짜   이름                                            작업
# 29  20220104  한소연  주간-5ES33707, 5ELE2607 도면작업\n야근-5ELE2607 도면작업
#           날짜   이름                                            작업
# 30  20220104  최보연  주간-5ES33707, 5ELE2607 도면작업\n야근-5EV42001 도면작업
#           날짜   이름                                  작업
# 31  20220104  심지현  주간-5ELE2607 도면작업\n야근-5EV42001 도면작업
#           날짜    이름                           작업
# 32  20220104  최종혁   주간 - 현장 대응, 이슈처리\n야근 - 이슈처리
#           날짜   이름                                              작업
# 33  20220104  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름  \
# 34  20220104  문진영
#
#                                                                   작업
# 34  주간 - RDHQ3001,6DMT2727 Revit 설계\n야근 - RDHQ3001,6DMT2727 Revit 설계
#           날짜   이름                                              작업
# 35  20220104  김도일  주간 - 6DRD2805 Revit 설계\n야근 - 6DRD2805 Revit 설계
#           날짜   이름                                              작업
# 36  20220104  김범석  주간 - 6IRT2503 Revit 설계\n야근 - 6DFP2719 Revit 설계
#           날짜   이름                                       작업
# 37  20220104  한예지  주간 - 6DBP5652 도면작업 \n야근 - 6DEP4207 도면작업
#           날짜   이름                                      작업
# 38  20220104  연예은  주간 - 6DBP5652 도면작업\n야근 - 6DCU3909 도면작업
#           날짜   이름                                               작업
# 39  20220104  박수미  주간 - 6DHQ5748,6DFN5542 도면작업\n야근 - 6DHQ5741 도면작업
#           날짜   이름  \
# 40  20220104  홍지훈
#
#                                                               작업
# 40  주간 - 6DSA5910 SCR 설계, 6DFN5541 TRAY 설계\n야근 - 6DSA5910 SCR 설계
#           날짜    이름  \
# 41  20220104  이영섭
#
#                                                                   작업
# 41  주간 - 6DMT5645,5646,5647 SCR’ 설계\n야근 - 6DMT5645,5646,5647 SCR’ 설계
#           날짜   이름                                                          작업
# 42  20220104  배소연  주간 - 6DSP5409, 6DSP5410 도면작업\n야근 - 6DSP5410, 6DFP5715 도면작업
#           날짜   이름  \
# 43  20220104  한규현
#
#                                                                      작업
# 43  주간 - 6DFP5628,6IHI4306,4307,4308 도면작업\n야근 - 6IHI4309,4310,4311 도면작업
#           날짜   이름  \
# 44  20220104  고필원
#
#                                                               작업
# 44  주간 - 6DFP2708, 6DSL2601 revit 도면작업\n야근 - 6DSL2601 revit 도면작업
#           날짜   이름          작업  Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 12  20220105  안응식  삼성디스플레이 출장          NaN         NaN         NaN
#
#    Unnamed: 14 Unnamed: 15
# 12         NaN         NaN
#           날짜   이름          작업  Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 13  20220105  김남일  삼성디스플레이 출장          NaN         NaN         NaN
#
#    Unnamed: 14 Unnamed: 15
# 13         NaN         NaN
#           날짜   이름  \
# 14  20220105  이형철
#
#                                                                                     작업  \
# 14  DDWorks 분석\n 1. Dinno.Hu3d 소스분석(~1/7)\n 2. DDWorks HookUpDesigner 비즈니스 로직 분석(~1/7)
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 14          NaN         NaN         NaN         NaN         NaN
#           날짜   이름  \
# 15  20220105  김원철
#
#                                                                     작업  \
# 15  DDWorks 개선\n1. 도면출도, 타공 레이블 표시(완료)\n2. 도면출도, 타공,더미박스 on/off 표시(완료)
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 15          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                        작업  Unnamed: 11  \
# 16  20220105  엄정숙  주간자금보고\n급여작업(~1/7)\n법인카드전표작성\n2022년 연차공지          NaN
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 16         NaN         NaN         NaN         NaN
#           날짜   이름                                     작업  Unnamed: 11  \
# 17  20220105  음종호  DDWorks\n1. 코드 분석 및 메뉴얼 확인(~1/7, 35%)          NaN
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 17         NaN         NaN         NaN         NaN
#           날짜   이름  \
# 18  20220105  구은비
#
#                                                                                                                                                                                                                                                       작업  \
# 18  DDWorks 기능 개선\n 1. 머터리얼 카테고리 UI 기능 개발(~1/5, 100%)\n 2. 프로퍼티 단축키 복사, 붙여넣기 버그 수정(~1/5, 100%)\n 3. Selection List 버그 수정(~1/5, 100%)\n 4. 객체 선택시 그룹 속성 오류 수정(~1/5, 100%)\n 5. Conditional Selection 기능 추가(~1/6, 50%)\n 6. 제작도면 버그 수정 및 단축키 추가(~1/7, 60%)
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 18          NaN         NaN         NaN         NaN         NaN
#           날짜   이름          작업  Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 19  20220105  김선홍  삼성디스플레이 출장          NaN         NaN         NaN
#
#    Unnamed: 14 Unnamed: 15
# 19         NaN         NaN
#           날짜  이름  \
# 20  20220105  강현
#
#                                                                                                                 작업  \
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-E1 수동정합성 검증 진행중\n  2) 4F-S3 추가 스캔구역 수동정합성 검증 완료\n 2. BIM 업데이트\n 3. BIM 반영
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 20          NaN         NaN         NaN         NaN         NaN
#           날짜   이름  \
# 21  20220105  우제민
#
#                                                                                                                 작업  \
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-E1 수동정합성 검증 진행중\n  2) 4F-S3 추가 스캔구역 수동정합성 검증 완료\n 2. BIM 업데이트\n 3. BIM 반영
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 21          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                              작업  \
# 22  20220105  방태훈  주간-5TCT3905 현장미팅, 5TCW3907, 5TCW3908 설계\n야근-없음
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 22          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                              작업  \
# 23  20220105  오세광  주간-5ESP2201, 5ESP2202 이슈해결, 5TCT3905 설계\n야근-없음
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 23          NaN         NaN         NaN         NaN         NaN
#           날짜    이름                                              작업  \
# 24  20220105  김병훈   주간-5ESP2201, 5ESP2202 이슈해결, 5ESP2202 설계\n야근-없음
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 24          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                       작업  Unnamed: 11 Unnamed: 12  \
# 25  20220105  윤태현  주간-5EV50110 업데이트\n야근-없음          NaN         NaN
#
#    Unnamed: 13 Unnamed: 14 Unnamed: 15
# 25         NaN         NaN         NaN
#           날짜   이름                       작업  Unnamed: 11 Unnamed: 12  \
# 26  20220105  김상우  주간-5EV50304 업데이트\n야근-없음          NaN         김상우
#
#    Unnamed: 13    Unnamed: 14 Unnamed: 15
# 26          주간  5EV50304 업데이트         NaN
#           날짜   이름                                 작업  Unnamed: 11 Unnamed: 12  \
# 27  20220105  박선미  주간-5EV42002, 5EV42001 도면작업\n야근-없음          NaN         박선미
#
#    Unnamed: 13 Unnamed: 14     Unnamed: 15
# 27          주간    5EV42002   5EV42001 도면작업
#           날짜   이름                                 작업  Unnamed: 11 Unnamed: 12  \
# 28  20220105  한소연  주간-5ESP2202, 5EV55901 도면작업\n야근-없음          NaN         한소연
#
#    Unnamed: 13 Unnamed: 14     Unnamed: 15
# 28          주간    5ESP2202   5EV55901 도면작업
#           날짜   이름                                 작업  Unnamed: 11 Unnamed: 12  \
# 29  20220105  최보연  주간-5EHS2703, 5EV42002 도면작업\n야근-없음          NaN         최보연
#
#    Unnamed: 13 Unnamed: 14     Unnamed: 15
# 29          주간    5EHS2703   5EV42002 도면작업
#           날짜   이름                                 작업  Unnamed: 11 Unnamed: 12  \
# 30  20220105  심지현  주간-5EV42001, 5EV42002 도면작업\n야근-없음          NaN         심지현
#
#    Unnamed: 13 Unnamed: 14     Unnamed: 15
# 30          주간    5EV42001   5EV42002 도면작업
#           날짜    이름                                                     작업  \
# 31  20220105  최종혁   주간 - 현장 대응, 이슈처리, RDSA6001 설계\n야근 - 이슈처리, RDSA6001 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 31          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                              작업  \
# 32  20220105  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 32          NaN         NaN         NaN         NaN         NaN
#           날짜    이름  \
# 33  20220105  문진영
#
#                                                                   작업  \
# 33  주간 - RDHQ3001,6DMT2727 Revit 설계\n야근 - RDHQ3001,6DMT2727 Revit 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 33          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                              작업  \
# 34  20220105  김도일  주간 - 6DRD2805 Revit 설계\n야근 - 6DRD2805 Revit 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 34          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                              작업  \
# 35  20220105  김범석  주간 - 6DFP2719 Revit 설계\n야근 - 6DBN2707 Revit 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 35          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                       작업  Unnamed: 11  \
# 36  20220105  한예지  주간 - 6IRT2503 도면작업 \n야근 - 6IRT2503 도면작업          NaN
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 36         NaN         NaN         NaN         NaN
#           날짜   이름                                                         작업  \
# 37  20220105  연예은  주간 - 6DCU3909,RDSA6001 도면작업\n야근 - 6DCU3909, RDSA6001 도면작업
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 37          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                           작업  Unnamed: 11 Unnamed: 12  \
# 38  20220105  박수미  주간 - 6DHQ5740 도면작업\n야근 - 없음          NaN         NaN
#
#    Unnamed: 13 Unnamed: 14 Unnamed: 15
# 38         NaN         NaN         NaN
#           날짜   이름                                                     작업  \
# 39  20220105  홍지훈  주간 - 6DSA5910, 6IHI4311 SCR 설계,\n야근 - 6DSA5910 SCR 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 39          NaN         NaN         NaN         NaN         NaN
#           날짜    이름  \
# 40  20220105  이영섭
#
#                                                                                 작업  \
# 40  주간 - 6DSA5918 REV. 6DFN5717, 6DSP5409 SCR’ 설계\n야근 - 6DMT5645,5646,5647 SCR’ 설계
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 40          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                                                작업  \
# 41  20220105  배소연  주간 - 6DSA6002, 6DHQ5748 도면작업\n야근 - 6DFN5715 도면작업
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 41          NaN         NaN         NaN         NaN         NaN
#           날짜   이름  \
# 42  20220105  한규현
#
#                                                               작업  Unnamed: 11  \
# 42  주간 - 6DBN2705, 2706,2707 TRAY 설계\n야근 - 6DBN2708,2709 TRAY 설계          NaN
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 42         NaN         NaN         NaN         NaN
#           날짜   이름  \
# 43  20220105  고필원
#
#                                                                                           작업  \
# 43  주간 - 6DFP2708, 6DBN2707, 6DSL2601 Revit 보강대 간섭확인\n야근 - 6IPP2508, 6DSL2607 Revit 보강대 간섭확인
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 43          NaN         NaN         NaN         NaN         NaN
#           날짜   이름                     작업
# 12  20220106  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220106  김남일
#
#                                                                                  작업
# 13  SK 정합성 검증 지원 출장\n신한항업 준공 처리\nDDWorks 개선\n 1. 타공 자동 배치 시 Eidt Lock 버그 수정(~1/7)
#           날짜   이름  \
# 14  20220106  이형철
#
#                                                                                     작업
# 14  DDWorks 분석\n 1. Dinno.Hu3d 소스분석(~1/7)\n 2. DDWorks HookUpDesigner 비즈니스 로직 분석(~1/7)
#           날짜   이름  \
# 15  20220106  김원철
#
#                                                                    작업
# 15  DDWorks 개선\n 1. BIM노즐에서 배관 훅업시 POC 설정창(완료)\n 2. 뷰잉 큐브(~1/10, 20%)
#           날짜   이름                                       작업
# 16  20220106  엄정숙  급여작업(~1/7)\n 1. 품의서작성\n 2. 급여 및 세금전표 작성
#           날짜   이름                                     작업
# 17  20220106  음종호  DDWorks\n1. 코드 분석 및 메뉴얼 확인(~1/7, 70%)
#           날짜   이름  \
# 18  20220106  구은비
#
#                                                                                                                                                                     작업
# 18  DDWorks 기능 개선\n 1. BIM 노즐 훅업시 사이즈 변경 UI(~1/6, 100%)\n 2. 그룹 머터리얼 UI 변경(~1/7, 80%)\n 3. Conditional Selection 기능 추가(~1/7, 80%)\n 4. 제작도면 버그 수정 및 단축키 추가(~1/11, 60%)
#           날짜   이름  \
# 19  20220106  김선홍
#
#                                                                                                                                                         작업
# 19  SK 에코플랜트\n 1. HookUp 객체 오차 리스트 추출(완료) \n 2. 사선 객체 라인표현 오류 수정(완료)\n 3. 오류 유형 추가 및 결과 Update 기능 개선(완료)\nDDWorks 개선\n 1. 노즐 기준 P&ID 기능\n 2. 설비 기준 P&ID 기능
#           날짜  이름                                                         작업
# 20  20220106  강현  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-E1/4F-N2 수동정합성 검증 완료
#           날짜   이름                                                         작업
# 21  20220106  우제민  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-E1/4F-N2 수동정합성 검증 완료
#           날짜   이름                        작업
# 22  20220106  방태훈  주간-M16미팅\n야근-5TCW4108 설계
#           날짜   이름                              작업
# 23  20220106  오세광  주간-5TCT3905 설계\n야근-5TCT3905 설계
#           날짜    이름                                    작업
# 24  20220106  김병훈   주간-5EHS4201 설계, 이슈대응\n야근-5EHS4201 설계
#           날짜   이름                                            작업
# 25  20220106  윤태현  주간-5EV50607, 5EGP4303 업데이트\n야근-5EGP4303 업데이트
#           날짜   이름                                            작업
# 26  20220106  김상우  주간-5ESP4302 업데이트\n야근-5ESP4302, 5ESP4303 업데이트
#           날짜   이름                                            작업
# 27  20220106  박선미  주간-5EV42001, 5EV42002 도면작업\n야근-5ELE2607 도면작업
#           날짜   이름                                        작업
# 28  20220106  한소연  주간-5EV42001 도면작업, 자재불출\n야근-5ES33707 도면작업
#           날짜   이름                                            작업
# 29  20220106  최보연  주간-5EV42002, 5EV55901 도면작업\n야근-5ES33707 도면작업
#           날짜   이름                                            작업
# 30  20220106  심지현  주간-5EV42002, 5ES33707 도면작업\n야근-5ES33707 도면작업
#           날짜    이름                                                     작업
# 31  20220106  최종혁   주간 - 현장 대응, 이슈처리, RDSA6001 설계\n야근 - 이슈처리, RDSA6001 설계
#           날짜   이름                                              작업
# 32  20220106  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름                                              작업
# 33  20220106  문진영   주간 - RDHQ3001 Revit 설계\n야근 - RDHQ3001 Revit 설계
#           날짜   이름                                              작업
# 34  20220106  김도일  주간 - 6DRD2805 Revit 설계\n야근 - 6DRD2805 Revit 설계
#           날짜   이름                                                    작업
# 35  20220106  김범석  주간 - 6DSL2601 TOXIC Revit 설계\n야근 - 6DBN2707 Revit 설계
#           날짜   이름                                       작업
# 36  20220106  한예지  주간 - 6DMT5646 도면작업 \n야근 - 6DSL2601 도면작업
#           날짜   이름                                      작업
# 37  20220106  연예은  주간 - 6DSA5910 도면작업\n야근 - 6DSA5910 도면작업
#           날짜   이름                                      작업
# 38  20220106  박수미  주간 - 6DSA5910 도면작업\n야근 - 6DSA5910 도면작업
#           날짜   이름                                         작업
# 39  20220106  홍지훈  주간 - 6DFN5617 TOXIC 설계\n야근 - 2,3차 TRAY 설계
#           날짜    이름  \
# 40  20220106  이영섭
#
#                                                                        작업
# 40  주간 - 6DSA5918 REV, 6DSA5906 이슈대응, 6DSD5716 U/T\n야근 - 6DSL5801 SCR’ 설계
#           날짜   이름  \
# 41  20220106  배소연
#
#                                                                       작업
# 41  주간 - 6DFN5542, 6IHI4311, 6DHQ5740 도면작업\n야근 - 6DHQ5740, 6DHQ5741 도면작업
#           날짜   이름  \
# 42  20220106  한규현
#
#                                                                     작업
# 42  주간 - 6DFP2705,2706 Revit TRAY 설계\n야근 - 6DFP2705,2706 Revit TRAY 설계
#           날짜   이름  \
# 43  20220106  고필원
#
#                                                                                    작업
# 43  주간 - 6DAN2606 Revit 보강대 간섭확인, 6DHQ2737 Revit TRAY 설계\n야근 - 6DHQ2737 Revit TRAY 설계
#           날짜   이름                     작업
# 12  20220107  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름                                                     작업
# 13  20220107  김남일  DDWorks 개선\n 1. 중복 로그인 시 기존 로그인 연결 종료 처리 및 테스트(~1/11)
#           날짜   이름  \
# 14  20220107  이형철
#
#                                                                                     작업
# 14  DDWorks 분석\n 1. Dinno.Hu3d 소스분석(~1/7)\n 2. DDWorks HookUpDesigner 비즈니스 로직 분석(~1/7)
#           날짜   이름                                 작업
# 15  20220107  김원철  DDWorks 개선\n 1. 뷰잉 큐브(~1/10, 60%)
#           날짜   이름                                       작업
# 16  20220107  엄정숙  급여작업(~1/7)\n 1. 품의서작성\n 2. 급여 및 세금전표 작성
#           날짜   이름                                       작업
# 17  20220107  음종호  DDWorks\n 1. 코드 분석 및 메뉴얼 확인(~1/7, 100%)
#           날짜   이름  \
# 18  20220107  구은비
#
#                                                                                                                                                                           작업
# 18  DDWorks 기능 개선\n 1. 그룹 머터리얼 UI 변경(~1/7, 100%)\n 2. 화각/워킹모드/BIM노즐사이즈 옵션값 추가(~1/7, 100%)\n 3. Conditional Selection 기능 추가(~1/10, 100%)\n 4. 제작도면 버그 수정 및 단축키 추가(~1/11, 60%)
#           날짜   이름  \
# 19  20220107  김선홍
#
#                                                                      작업
# 19  DDWorks 개선\n 1. 노즐 기준 P&ID 기능(~1/11, 40%)\n 2. 설비 기준 P&ID 기능(~1/14)
#           날짜  이름  \
# 20  20220107  강현
#
#                                                                                                              작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-B5 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 4차 납품 전 최종 BIM 업데이트 완료\n 3. BIM 반영
#           날짜   이름  \
# 21  20220107  우제민
#
#                                                                                                              작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-B5 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 4차 납품 전 최종 BIM 업데이트 완료\n 3. BIM 반영
#           날짜   이름                       작업
# 22  20220107  방태훈  주간-5TCW4107 현장대응\n야근-없음
#           날짜   이름                     작업
# 23  20220107  오세광  주간-5TCT3905 설계\n야근-없음
#           날짜    이름                           작업
# 24  20220107  김병훈   주간-5EHS4201 설계, 이슈대응\n야근-없음
#           날짜   이름                       작업
# 25  20220107  윤태현  주간-5EGP4303 업데이트\n야근-없음
#           날짜   이름                       작업
# 26  20220107  김상우  주간-5ESP4303 업데이트\n야근-없음
#           날짜   이름                       작업
# 27  20220107  박선미  주간-5EV50110 도면작업\n야근-없음
#           날짜   이름                                           작업
# 28  20220107  한소연  주간-5ESP2201, 5ESP2202, 5ES33705 도면작업\n야근-없음
#           날짜   이름                                                     작업
# 29  20220107  최보연  주간-5EV55901, 5ES33707, 5EV50109, 5ES33801 도면작업\n야근-없음
#           날짜   이름                                 작업
# 30  20220107  심지현  주간-5EV55901, 5EV50110 도면작업\n야근-없음
#           날짜    이름  작업
# 31  20220107  최종혁   연차
#           날짜   이름                                              작업
# 32  20220107  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름                                              작업
# 33  20220107  문진영   주간 - RDHQ3001 Revit 설계\n야근 - RDHQ3001 Revit 설계
#           날짜   이름                                              작업
# 34  20220107  김도일  주간 - 6DFP2711 Revit 설계\n야근 - 6DFP2711 Revit 설계
#           날짜   이름                                              작업
# 35  20220107  김범석  주간 - 6DBN2707 Revit 설계\n야근 - 6DBN2707 Revit 설계
#           날짜   이름                                       작업
# 36  20220107  한예지  주간 - 6DSL2601 도면작업 \n야근 - 6DSL2601 도면작업
#           날짜   이름                                           작업
# 37  20220107  연예은  주간 - 출도 및 6DFN5645 도면작업\n야근 - 6DFN5645 도면작업
#           날짜   이름                                      작업
# 38  20220107  박수미  주간 - 6DEP4207 도면작업\n야근 - 6DEP4207 도면작업
#           날짜   이름                                            작업
# 39  20220107  홍지훈  주간 - 현장 대응 및 2,3차 TRAY 설계\n야근 - 2,3차 TRAY 설계
#           날짜    이름  \
# 40  20220107  이영섭
#
#                                                                        작업
# 40  주간 - 6DSA5906, 6DSP5410 이슈대응, 6DSL5801 SCR’ 설계\n야근 - 6DSL5801 SCR’ 설계
#           날짜   이름                                                      작업
# 41  20220107  배소연  주간 - 6DHQ5740, 6DHQ5741 도면작업및 도면정리\n야근 - 6DFN5541 도면작업
#           날짜   이름  \
# 42  20220107  한규현
#
#                                                                     작업
# 42  주간 - 6DFP2707,2708 Revit TRAY 설계\n야근 - 6DFP2708,2709 Revit TRAY 설계
#           날짜   이름                                      작업
# 43  20220107  고필원  주간 - Revit TRAY 설계\n야근 - Revit TRAY 설계
#           날짜   이름                     작업
# 12  20220110  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220110  김남일
#
#                                                                                          작업
# 13  DDWorks 개선\n 1. 중복 로그인 시 기존 로그인 연결 종료 처리 및 테스트(~1/11)\n 2. 추가되지 않은 객체 Lock 버그 수정(~1/12)
#           날짜   이름  \
# 14  20220110  이형철
#
#                                                                                                                      작업
# 14  DDWorks 분석\n 1. DDWorks HookUpDesigner Ribbon Menu 개선안 마련 (~1/11)\n 2. DDWorks Conditional Selection 버그 테스트 (~1/10)
#           날짜   이름  \
# 15  20220110  김원철
#
#                                                                      작업
# 15  DDWorks 개선\n1. 뷰잉 큐브(~1/11, 90%)\n시공정합성\n1. 터널데이터 포인트 추출(~1/11,70%)
#           날짜   이름                                                       작업
# 16  20220110  엄정숙  급여지급, 세금납부 년결산(~1/15)\n 1. 부가세신고작성\n 2. 한양이엔지 연결 패키지 작성
#           날짜   이름  \
# 17  20220110  음종호
#
#                                                                                        작업
# 17  DDWorks\n1. ddworks 코드 분석(~1/14, 20%)\n2. wpf DevExporess Reference Check(~1/14, 10%)
#           날짜   이름  \
# 18  20220110  구은비
#
#                                                                                                                                                                                작업
# 18  DDWorks 기능 개선\n 1. Conditional Selection 기능 추가(~1/10, 100%)\n 2. 서버 유저 정보 조회 UI 기능(~1/11, 90%)\n 3. 제작도면 버그 수정 및 단축키 추가(~1/11, 90%)\n 4. 제작도면 기자재 BOM 상세 부품 등록 UI(~1/13, 10%)
#           날짜   이름  \
# 19  20220110  김선홍
#
#                                                                                                                                          작업
# 19  DDWorks 개선\n 1. 노즐 기준 P&ID 기능(~1/11, 90%)\n 2. BIM Export/Import 로그 기능(~1/11)\n 3. 설비 기준 P&ID 기능\nSK 에코플랜트\n 1. HookUp 객체 리스트 추출 수정(완료)
#           날짜  이름  \
# 20  20220110  강현
#
#                                                                                                   작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-B5 수동정합성 검증 완료\n  2) 5F-A4 수동정합성 검증 진행중\n  3) 주간보고 문서 작성 완료
#           날짜   이름  \
# 21  20220110  우제민
#
#                                                                                                   작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-B5 수동정합성 검증 완료\n  2) 5F-A4 수동정합성 검증 진행중\n  3) 주간보고 문서 작성 완료
#           날짜   이름                            작업
# 22  20220110  방태훈  주간-5TCW4115 이슈협의 현장대응\n야근-없음
#           날짜   이름                     작업
# 23  20220110  오세광  주간-5TCT3905 설계\n야근-없음
#           날짜    이름                     작업
# 24  20220110  김병훈   주간-5EHS4201 설계\n야근-없음
#           날짜   이름                       작업
# 25  20220110  윤태현  주간-5EGP4303 업데이트\n야근-없음
#           날짜   이름                       작업
# 26  20220110  김상우  주간-5ESP4303 업데이트\n야근-없음
#           날짜   이름                       작업
# 27  20220110  박선미  주간-5EV55901 도면작업\n야근-없음
#           날짜   이름                                           작업
# 28  20220110  한소연  주간-5TCW4107, 5TCT3905, 5ES33705 도면작업\n야근-없음
#           날짜   이름                       작업
# 29  20220110  최보연  주간-5ES33801 도면작업\n야근-없음
#           날짜   이름                                           작업
# 30  20220110  심지현  주간-5TCT3905, 5ES33707, 5ESP4302 도면작업\n야근-없음
#           날짜    이름                                                     작업
# 31  20220110  최종혁   주간 - 현장 대응, 이슈처리, RDSA6001 설계\n야근 - 이슈처리, RDSA6001 설계
#           날짜   이름                                              작업
# 32  20220110  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름                                              작업
# 33  20220110  문진영   주간 - RDHQ3001 Revit 설계\n야근 - RDHQ3001 Revit 설계
#           날짜   이름                                              작업
# 34  20220110  김도일  주간 - 6DFP2711 Revit 설계\n야근 - 6DFP2711 Revit 설계
#           날짜   이름                                              작업
# 35  20220110  김범석  주간 - RDIG2801 Revit 설계\n야근 - RDIG2801 Revit 설계
#           날짜   이름                                       작업
# 36  20220110  한예지  주간 - 6DSL2601 도면작업 \n야근 - 6DSL2601 도면작업
#           날짜   이름                                                작업
# 37  20220110  연예은  주간 - 6DFN5645, 6DMT5647 도면작업\n야근 - 6DMT5647 도면작업
#           날짜   이름                                      작업
# 38  20220110  박수미  주간 - 6DEP4207 도면작업\n야근 - 6DEP4207 도면작업
#           날짜   이름                                                      작업
# 39  20220110  홍지훈  주간 - 2,3차 TRA, 배관 설계\n야근 - 2,3차 TRAY, 배관 설계, 이슈 및 정보추출
#           날짜    이름  \
# 40  20220110  이영섭
#
#                                                                        작업
# 40  주간 - 6DSA5906 이슈대응, 6DFN5646,6DMT5647 SCR REV.\n야근 - 6DSL5801 SCR’ 설계
#           날짜   이름                                      작업
# 41  20220110  배소연  주간 - 6DFP5617 도면작업\n야근 - 6DFP5617 도면작업
#           날짜   이름  \
# 42  20220110  한규현
#
#                                                                                 작업
# 42  주간 - 6DFP2711,2712,2713,2714,2715 Revit TRAY 설계\n야근 - 6DDMT5646,5647,5648 도면작업
#           날짜   이름  \
# 43  20220110  고필원
#
#                                                                      작업
# 43  주간 - 6DFN2732,2731,2730, 6DMT2729 Revit TRAY 설계\n야근 - 6IPP2508 도면작업
#           날짜   이름                     작업
# 12  20220111  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220111  김남일
#
#                                                                                       작업
# 13  DDWorks 개선\n 1. 중복 로그인 시 기존 로그인 연결 종료 처리 및 테스트(완료)\n 2. 추가되지 않은 객체 Lock 버그 수정(~1/12)
#           날짜   이름  \
# 14  20220111  이형철
#
#                                                                                                                      작업
# 14  DDWorks 분석\n 1. DDWorks HookUpDesigner Ribbon Menu 개선안 마련 (~1/12)\n 2. DDWorks Conditional Selection 버그 테스트 (~1/11)
#           날짜   이름  \
# 15  20220111  김원철
#
#                                                                                      작업
# 15  DDWorks 개선\n1. 뷰잉 큐브(완료)\n2. BIM노즐에서 배관 훅업시 POC 설정창(완료)\n시공정합성\n1. 터널데이터 포인트 추출(완료)
#           날짜   이름                                            작업
# 16  20220111  엄정숙  년결산(~1/15)\n 1. 부가세신고작성\n 2. 한양이엔지 연결 패키지 작성
#           날짜   이름  \
# 17  20220111  음종호
#
#                                                                                        작업
# 17  DDWorks\n1. ddworks 코드 분석(~1/14, 40%)\n2. wpf DevExporess Reference Check(~1/14, 40%)
#           날짜   이름  \
# 18  20220111  구은비
#
#                                                                                                                                                                                                                                                                      작업
# 18  DDWorks 기능 개선\n 1. Conditional Selection 버그 수정(~1/11, 100%)\n 2. 서버 유저 정보 조회 UI 기능(~1/11, 100%)\n 3. Selection List 업데이트 안되도록 변경(~1/11, 100%)\n 4. BIM 노즐 훅업시 사이즈 변경 UI 수정(~1/11, 100%)\n 5. 제작도면 버그 수정 및 단축키 추가(~1/11, 100%)\n 6. 제작도면 기자재 상세 부품 등록 UI(~1/13, 10%)
#           날짜   이름  \
# 19  20220111  김선홍
#
#                                                                                                                                 작업
# 19  DDWorks 개선\n 1 . BIM Export/Import 로그 기능(완료)\n 2. 노즐 기준 P&ID 기능(~1/12, 90%)\n 3. 설비 기준 P&ID 기능\n정합성분석\n 1. 터널 정합성분석 테스트(~1/12)
#           날짜  이름  \
# 20  20220111  강현
#
#                                                                                                        작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-A4 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 추가 BIM 업데이트 진행 완료(Duct File)
#           날짜   이름  \
# 21  20220111  우제민
#
#                                                                                                        작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-A4 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 추가 BIM 업데이트 진행 완료(Duct File)
#           날짜   이름                            작업
# 22  20220111  방태훈  주간-5TCW4108 이슈협의\n야근-이슈 현장대응
#           날짜   이름                              작업
# 23  20220111  오세광  주간-5TCT3905 설계\n야근-5TCT3905 설계
#           날짜    이름                                      작업
# 24  20220111  김병훈   주간-5EHS4201 설계, 장비개발요청\n야근-5EHS4201 설계
#           날짜   이름                                  작업
# 25  20220111  윤태현  주간-5EGP4303 업데이트\n야근-5EGP4303 업데이트
#           날짜   이름                                  작업
# 26  20220111  김상우  주간-5ESP4303 업데이트\n야근-5ESP4303 업데이트
#           날짜   이름                            작업
# 27  20220111  박선미  주간-5EV50110 도면작업\n야근-익스포트 작업
#           날짜   이름                                  작업
# 28  20220111  한소연  주간-5TCW4106 도면작업\n야근-5TCW4106 도면작업
#           날짜   이름                             작업
# 29  20220111  최보연  주간-5ES33801 도면작업\n야근-5TCW4108
#           날짜   이름                                                     작업
# 30  20220111  심지현  주간-5ESP4302, 5EV50110, 5E33801 도면작업\n야근-5ES33801 도면작업
#           날짜    이름                                                     작업
# 31  20220111  최종혁   주간 - 현장 대응, 이슈처리, RDSA6001 설계\n야근 - 이슈처리, RDSA6001 설계
#           날짜   이름                                              작업
# 32  20220111  최용훈  주간 - 6DAN2602 Revit 설계\n야근 - 6DAN2602 Revit 설계
#           날짜    이름                                              작업
# 33  20220111  문진영   주간 - RDHQ3001 Revit 설계\n야근 - 6DFP2708 Revit 설계
#           날짜   이름                                  작업
# 34  20220111  김도일  주간 - 6DSA5914 설계\n야근 - 6DSA5914 설계
#           날짜   이름                                              작업
# 35  20220111  김범석  주간 - RDIG2801 Revit 설계\n야근 - RDIG2801 Revit 설계
#           날짜   이름                                                 작업
# 36  20220111  한예지  주간 - 6DSL2601, 6DRD2805 도면작업 \n야근 - 6DRD2805 도면작업
#           날짜   이름                                                작업
# 37  20220111  연예은  주간 - 6DFN5714, 6DMT5647 도면작업\n야근 - 6DSL5801 도면작업
#           날짜   이름                                      작업
# 38  20220111  박수미  주간 - 6DSL5801 도면작업\n야근 - 6DSL5801 도면작업
#           날짜   이름                                        작업
# 39  20220111  홍지훈  주간 - 2,3차 TRAY 설계\n야근 - 6DFP5611 SCR’ 설계
#           날짜    이름                                            작업
# 40  20220111  이영섭   주간 - 6DSL5801 SCR’ 설계\n야근 - 6DSL5606 SCR’ 설계
#           날짜   이름                                                       작업
# 41  20220111  배소연  주간 - 6DFN5541, 6DBP5547 도면작업 및 도면정리\n야근 - 6DBP5547 도면작업
#           날짜   이름  \
# 42  20220111  한규현
#
#                                                                          작업
# 42  주간 - 6DMT5649 도면작업, 6DFP2713 Revit TRAY 설계\n야근 - 6DFP2713 Revit TRAY 설계
#           날짜   이름                                               작업
# 43  20220111  고필원  주간 - 6DBN2707 도면작업\n야근 - 6DMT2728 Revit TRAY 설계
#           날짜   이름                     작업
# 12  20220117  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220117  김남일
#
#                                                                                                                        작업
# 13  DDWorks 개선\n 1. Commit Version Check Sql 수정(완료)\n 2. Server 종료 시 클라이언트 종료 처리(~1/18)\n 3. 추가되지 않은 객체 Lock 버그 수정(~1/18)
#           날짜   이름  \
# 14  20220117  이형철
#
#                                                                      작업
# 14  DDWorks 분석\n 1. Dinno2Revit Add-in 소스분석(~1/18)\n 2. CAT 환경세팅(~1/17)
#           날짜   이름                                       작업
# 15  20220117  김원철  DDWorks 개선\n1.  도면출도시 멀티라인 타공 에러 수정(완료)
#           날짜   이름                                     작업
# 16  20220117  엄정숙  연말정산\n2022년 급여 업데이트\n취업규칙 확정 신고(~1/31
#           날짜   이름  \
# 17  20220117  음종호
#
#                                                                                                                                             작업
# 17  DDWorks 개선\n 1. DDWorks Client User 정보 가입 요청 추가 및 테스트 (~1/18, 90%)\nDDWorksWebManager(Uams) 개선\n 1. DDWork Client 승인 추가 및 테스트 (~1/18, 90%)
#           날짜   이름  \
# 18  20220117  구은비
#
#                                                                                  작업
# 18  DDWorks 기능 개선\n 1. 서버 IP 필터링 기능 개발(~1/18, 70%)\n 2. 서버 유저 조회 UI 기능 개선(~1/20, 0%
#           날짜   이름  \
# 19  20220117  김선홍
#
#                                                                                                                                                                   작업
# 19  위프코 SCAP 설치 및 교육(완료)\n삼성물산 PC반출(완료)\n삼성 SDC PC 5대 반입준비(~1/18)\nDDWorks 개선\n 1. 기자재 머터리얼 매핑기능 개선(~01/21)\n 2. 노즐 기준 P&ID 기능(~1/21, 90%)\n 3. 설비 기준 P&ID 기능(~1/21)
#           날짜  이름  \
# 20  20220117  강현
#
#                                                                                                                                         작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-N3 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 1월 3주차 BIM 업데이트 완료\n 3. BIM 반영\n  1) 1월 26일 납품구역 BIM 업데이트 진행중
#           날짜   이름  \
# 21  20220117  우제민
#
#                                                                                                                                         작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-N3 수동정합성 검증 진행중\n 2. BIM 업데이트\n  1) 1월 3주차 BIM 업데이트 완료\n 3. BIM 반영\n  1) 1월 26일 납품구역 BIM 업데이트 진행중
#           날짜   이름                                      작업
# 22  20220117  방태훈  주간-5TCW4115 현장대응\n야근-5TCW4115 이슈협의, 설계
#           날짜   이름                                          작업
# 23  20220117  오세광  주간-E39C4F6-8182, 81, 82 설계\n야근-5TCT3905 설계
#           날짜    이름                                            작업
# 24  20220117  김병훈   주간-E40CH3F-0302, 5ETM0601 설계\n야근-5ETM0601 설계
#           날짜   이름                      작업
# 25  20220117  윤태현  주간-정산 캡쳐작업\n야근-정산 캡쳐작업
#           날짜   이름                      작업
# 26  20220117  김상우  주간-정산 캡쳐작업\n야근-정산 캡쳐작업
#           날짜   이름                       작업
# 27  20220117  박선미  주간-5TCW4106 도면작업\n야근-없음
#           날짜   이름                                                         작업
# 28  20220117  한소연  주간-E40SF6-0309, 5ELE2607, 5TCW4108 도면작업\n야근-5TCW4108 도면작업
#           날짜   이름                                               작업
# 29  20220117  최보연  주간-E40CF4-0603, 5ELE2607 도면작업\n야근-5ELE2607 도면작업
#           날짜   이름  \
# 30  20220117  심지현
#
#                                                                      작업
# 30  주간-5EV41902, E40COS-0901, 5ELE2607 도면작업\n야근-5ELE2607, 5EHS4201 도면작업
#           날짜    이름                                                     작업
# 31  20220117  최종혁   주간 - 현장 대응, 이슈처리, RDSA6001 설계\n야근 - 이슈처리, RDSA6001 설계
#           날짜   이름                                           작업
# 32  20220117  최용훈  주간 - 6DEP2710 SCR  설계\n야근 - 6DEP2710 SCR 설계
#           날짜    이름                                              작업
# 33  20220117  문진영   주간 - 6DEP2708 Revit 설계\n야근 - RDHQ3001 Revit 설계
#           날짜   이름                                  작업
# 34  20220117  김도일  주간 - 6DSA5914 설계\n야근 - 6DSA5914 설계
#           날짜   이름                                              작업
# 35  20220117  김범석  주간 - 6DAN2602 Revit 설계\n야근 - 6DBN2707 Revit 설계
#           날짜   이름                                       작업
# 36  20220117  한예지  주간 - 6DAN2707 도면작업 \n야근 - 6DAN2707 도면작업
#           날짜   이름                                      작업
# 37  20220117  연예은  주간 - 6DCU3909 도면작업\n야근 - 6DSD5716 도면작업
#           날짜   이름                           작업
# 38  20220117  박수미  주간 - 6DFP5611 도면작업\n야근 - 없음
#           날짜   이름                                                   작업
# 39  20220117  홍지훈  주간 - 6DSD5716,6DFP5604 SCR 설계\n야근 - 6DFP5604 SCR 설계
#           날짜    이름                                            작업
# 40  20220117  이영섭   주간 - 6DFP5634 SCR’ 설계\n야근 - 6DFP5634 SCR’ 설계
#           날짜   이름                                      작업
# 41  20220117  배소연  주간 - 6DSP4214 도면작업\n야근 - 반납도면, 원본도면 정리
#           날짜   이름                                                작업
# 42  20220117  한규현  주간 - 2,3차 TRAY REVIT 설계\n야근 - 2,3차 TRAY REVIT 설계
#           날짜   이름                     작업
# 12  20220118  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220118  김남일
#
#                                                                                                       작업
# 13  DDWorks 개선\n 1. Server 종료 시 클라이언트 종료 처리(완료)\n 2. DDWorks User 계정 요청 기능 추가(완료)\n 3. 삼성 SDC PC 5대 반입준비
#           날짜   이름                               작업
# 14  20220118  이형철  DDWorks 분석\n 1. CAT 소스분석(~1/21)
#           날짜   이름  \
# 15  20220118  김원철
#
#                                                                                       작업
# 15  DDWorks 개선\n1. Shift/Ctrl 누르고 객체선택시 딜레이 수정(완료)\n제작도면\n1. Reducer/RTEE 관경이상 버그 수정(완료)
#           날짜   이름  \
# 16  20220118  엄정숙
#
#                                                                                    작업
# 16  년결산 수정사항 반영(완료)\n연말정산\n취업규칙 확정 신고(~1/31)\n외주계약확인\n 1. 숙소\n 2. 입사자(근로계약서+4대보험가입 등)
#           날짜   이름  \
# 17  20220118  음종호
#
#                                                                                                                                                                                 작업
# 17  DDWorks 기능 개선\n 1. DDWorks Client User 정보 가입 요청 추가 및 테스트 (~1/18, 완료)\nDDWorksWebManager(Uams)\n 1. DDWork Client 승인 추가 및 테스트 (~1/18, 완료)\n 2. 유저 등록, 수정시 Memo 기능 추가(~1/18, 완료)
#           날짜   이름  \
# 18  20220118  구은비
#
#                                                                                      작업
# 18  DDWorks 기능 개선\n 1. 서버 IP 필터링 기능 개발(~1/18, 100%)\n 2. 서버 유저 조회 UI 기능 개선(~1/18, 100%)
#           날짜   이름  \
# 19  20220118  김선홍
#
#                                                                                                                                                         작업
# 19  삼성 SDC PC 5대 반입준비(완료)\n삼성 SDC  출장 및 PC 5대 반입(01/19)\nDDWorks 개선\n 1. 기자재 머터리얼 매핑기능 개선(~01/21)\n 2. 노즐 기준 P&ID 기능(~1/21, 90%)\n 3. 설비 기준 P&ID 기능(~1/21)
#           날짜  이름  \
# 20  20220118  강현
#
#                                                                                                                                                                작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-N3 수동정합성 검증 완료\n  2) 4F-N1 수동정합성 검증 진행중\n  3) 5F-S1 수동정합성 검증 진행중\n 2. BIM 업데이트\n 3. BIM 반영\n  1) 1월 26일 납품구역 BIM 업데이트 완료
#           날짜   이름  \
# 21  20220118  우제민
#
#                                                                                                                                                                작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 4F-N3 수동정합성 검증 완료\n  2) 4F-N1 수동정합성 검증 진행중\n  3) 5F-S1 수동정합성 검증 진행중\n 2. BIM 업데이트\n 3. BIM 반영\n  1) 1월 26일 납품구역 BIM 업데이트 완료
#           날짜   이름                                작업
# 22  20220118  방태훈  주간-5TCW4106 이슈대응\n야근-5TCW4106 설계
#           날짜   이름                                  작업
# 23  20220118  오세광  주간-E39C4F6-8182.설계\n야근-5TCT3905 설계
#           날짜    이름                                         작업
# 24  20220118  김병훈   주간-E38Cl2-12, 5ETM0601 설계\n야근-5ESP4202 설계
#           날짜   이름                            작업
# 25  20220118  윤태현  주간-정산 캡쳐작업\n야근-5EHS2806 업데이트
#           날짜   이름                            작업
# 26  20220118  김상우  주간-정산 캡쳐작업\n야근-5EV40212 업데이트
#           날짜   이름                                  작업
# 27  20220118  박선미  주간-5TCW4108 도면작업\n야근-5TCW4108 도면작업
#           날짜   이름                                            작업
# 28  20220118  한소연  주간-5TCW4108 도면작업\n야근-5TCW4108, 5EHS4201 도면작업
#           날짜   이름                                  작업
# 29  20220118  최보연  주간-5EHS4201 도면작업\n야근-5EHS4201 도면작업
# ...
# 14  20220125  이형철  DDWorks 분석\n 1. 삼성 SDC PC7대 세팅(완료)\n 2. Hookup 테스트 (~1/28)
#           날짜   이름                                                          작업
# 15  20220125  김원철  DDWorks 개선\n1. 테스트 및 버그수정(~1/28)\n2. 설비/타공 임포트,익스포트(~1/27)
#           날짜   이름                                             작업
# 16  20220125  엄정숙  연이천 SK 현장 숙소 계약완료\n부가세 및 경비 지급완료\n연말정산(~2/28)
#           날짜   이름  \
# 17  20220125  음종호
#
#                                                                                                                                                                                        작업
# 17  DDWorks\n 1. 사용자 요청 수정 추가(~1/26, 30%)\nDDWorksWebManager(Uams)\n 1. 사용자 요청 승인시 권한 및 수정 팝업 기존 유저 팝업으로 변경(~1/25, 완료)\n신한항업 연구과제(Web3D)\n 1. publish 새 프로젝트 추가 후 텍스처 로딩 안되는 현상 수정(~1/25)
#           날짜   이름  \
# 18  20220125  구은비
#
#                                                                                                                                                                          작업
# 18  DDWorks 기능 개선\n 1. Selection List UI 수정(~1/25, 100%)\n 2. Change Equipment 검색 기능 추가(~1/25, 100%)\n 3. 그룹 트리 검색 정확도 높임(~1/25, 100%)\n 4. 프로퍼티창에서 POC 클릭시 이동(~1/25, 100%)
#           날짜   이름  \
# 19  20220125  김선홍
#
#                                                                                                  작업
# 19  DDWorks 개선\n 1. 기자재 변환 PipeSize 매핑(완료)\n 2. 노즐 기준 P&ID 기능\n 3. 설비 기준 P&ID 기능\n삼성 SDC  출장(01/26)
#           날짜  이름  \
# 20  20220125  강현
#
#                                                                                                                                       작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-A1 수동정합성 검증 완료\n  2) 5F-C2 수동정합성 검증 진행중\n  3) 6-2차 납품구역 문서 작성 후 송부 완료\n 2. BIM 업데이트\n 3. BIM 반영
#           날짜   이름  \
# 21  20220125  우제민
#
#                                                                                                                                       작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-A1 수동정합성 검증 완료\n  2) 5F-C2 수동정합성 검증 진행중\n  3) 6-2차 납품구역 문서 작성 후 송부 완료\n 2. BIM 업데이트\n 3. BIM 반영
#           날짜   이름                              작업
# 22  20220125  방태훈  주간-5EV45901 설계\n야근-5EV45901 설계
#           날짜   이름                                                작업
# 23  20220125  오세광  주간-5TCT4115,5EV60401 설계\n야근-5TCT4115,5EV60401 설계
#           날짜    이름                                        작업
# 24  20220125  김병훈   주간-5ESP4202 설계\n야근-5EHS4201, 5PCD4504 설계
#           날짜   이름                                  작업
# 25  20220125  윤태현  주간-5EHS2806 업데이트\n야근-5EHS2806 업데이트
#           날짜   이름                                  작업
# 26  20220125  김상우  주간-5EV50312 업데이트\n야근-5EV50312 업데이트
#           날짜   이름                                  작업
# 27  20220125  박선미  주간-5ESP4202 도면작업\n야근-5EHS2806 도면작업
#           날짜   이름                                  작업
# 28  20220125  한소연  주간-5EV45901 도면작업\n야근-5EV45901 도면작업
#           날짜   이름                                           작업
# 29  20220125  최보연  주간-5ESP4202, 5EV40108도면작업\n야근-5EV40108 도면작업
#           날짜   이름                                  작업
# 30  20220125  심지현  주간-5EV45901 도면작업\n야근-5EV40108 도면작업
#           날짜    이름                           작업
# 31  20220125  최종혁   주간 - 현장 대응, 이슈처리\n야근 - 이슈처리
#           날짜   이름                                  작업
# 32  20220125  최용훈  주간 - 6DAN2606 설계\n야근 - 6DPN2701 설계
#           날짜    이름                                              작업
# 33  20220125  문진영   주간 - 6DFN2733 Revit 설계\n야근 - 6DBN2706 Revit 설계
#           날짜   이름                                              작업
# 34  20220125  김도일  주간 - 6DFP2711 Revit 설계\n야근 - 6DFP2711 Revit 설계
#           날짜   이름                                              작업
# 35  20220125  김범석  주간 - RDIG2801 Revit 설계\n야근 - RDIG2801 Revit 설계
#           날짜   이름                                                 작업
# 36  20220125  한예지  주간 - 6DAN2602 도면작업 \n야근 - 6IPP2608, 6DSL2607 도면작업
#           날짜   이름                                             작업
# 37  20220125  연예은  주간 - 도면출도 및 6DFP5638 도면작업\n야근 - 6DFP5638 도면작업
#           날짜   이름                                      작업
# 38  20220125  박수미  주간 - 6DSA5912 도면작업\n야근 - 6DSA5911 도면작업
#           날짜   이름                                                   작업
# 39  20220125  홍지훈  주간 - 6DSP4214 SCR 설계, 6DSA6003 설계\n야근 - 6DSA6003 설계
#           날짜    이름  \
# 40  20220125  이영섭
#
#                                                                                 작업
# 40  주간 - 4F SCR Revit 교육 및 6DFN2711 SCR 설계\n야근 - 4F SCR Revit 교육 및 6DFN2711 SCR 설계
#           날짜   이름                                                    작업
# 41  20220125  배소연  주간 - 6DFN5715 도면작업 및 도면출력\n야근 - 6DFN5715 도면작업 및 도면정리
#           날짜   이름                                      작업
# 42  20220125  한규현  주간 - 6DSA5911 도면작업\n야근 - 6DSA5911 도면작업
#           날짜   이름                     작업
# 12  20220128  안응식  삼성디스플레이 DDWorks 납품 지원
#           날짜   이름  \
# 13  20220128  김남일
#
#                                                                          작업
# 13  삼성디스플레이 DDWorks 납품 지원\n'DDWorks 개선\n 1. Support Anchor bolt 기능 추가(~2/4)
#           날짜   이름                                  작업
# 14  20220128  이형철  DDWorks 분석\n 1. Hookup 테스트 (~1/28)
#           날짜   이름                                  작업
# 15  20220128  김원철  DDWorks 개선\n 1. 서포트 전산 볼트 개편(~2/7)
#           날짜   이름                 작업
# 16  20220128  엄정숙  급여작업\n연말정산(~2/28)
#           날짜   이름  작업
# 17  20220128  음종호  연차
#           날짜   이름  \
# 18  20220128  구은비
#
#                                                                                                                       작업
# 18  DDWorks 기능 개선\n 1. BIM Attribute 정제 기능(~2/3, 70%)\n 2. 서포트 앵커볼트 UI(~2/3, 0%)\n 3. Layout Import/Export UI(~2/4, 80%)
#           날짜   이름                     작업
# 19  20220128  김선홍  삼성디스플레이 DDWorks 납품 지원
#           날짜  이름  \
# 20  20220128  강현
#
#                                                                                        작업
# 20  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-B1/B3 수동정합성 검증 진행중\n  2) 5F-N6 N7 자동정합성 검증 진행 완료
#           날짜   이름  \
# 21  20220128  우제민
#
#                                                                                        작업
# 21  SK 에코플랜트 정합성 검증\n 1. 정합성 검증\n  1) 5F-B1/B3 수동정합성 검증 진행중\n  2) 5F-N6 N7 자동정합성 검증 진행 완료
#           날짜   이름  작업
# 22  20220128  방태훈  연차
#           날짜   이름  작업
# 23  20220128  오세광  연차
#           날짜    이름  작업
# 24  20220128  김병훈   연차
#           날짜   이름  작업
# 25  20220128  윤태현  연차
#           날짜   이름  작업
# 26  20220128  김상우  연차
#           날짜   이름  작업
# 27  20220128  박선미  연차
#           날짜   이름  작업
# 28  20220128  한소연  연차
#           날짜   이름  작업
# 29  20220128  최보연  연차
#           날짜   이름  작업
# 30  20220128  심지현  연차
#           날짜    이름                         작업
# 31  20220128  최종혁   주간 - 현장 대응, 이슈처리\n야근 - 없음
#           날짜   이름                         작업
# 32  20220128  최용훈  주간 - 6DPN2701 설계\n야근 - 없음
#           날짜    이름                               작업
# 33  20220128  문진영   주간 - RDHQ3001 Revit 설계\n야근 - 없음
#           날짜   이름                               작업
# 34  20220128  김도일  주간 - 6DFP2711 Revit 설계\n야근 - 없음
#           날짜   이름                               작업
# 35  20220128  김범석  주간 - RDIG2801 Revit 설계\n야근 - 없음
#           날짜   이름                            작업
# 36  20220128  한예지  주간 - 6DFP2711 도면작업 \n야근 - 없음
#           날짜   이름                           작업
# 37  20220128  연예은  주간 - 6DSA5914 도면작업\n야근 - 없음
#           날짜   이름                           작업
# 38  20220128  박수미  주간 - 6DFP2711 도면작업\n야근 - 없음
#           날짜   이름                                  작업
# 39  20220128  홍지훈  주간 - 6DSA5913 설계\n야근 - 6DSA5913 설계
#           날짜    이름  \
# 40  20220128  이영섭
#
#                                                                   작업
# 40  주간 - 6DFN2710, 2711 SCR 설계\n야근 - 6DFN2710, 2711, RDIG2801 SCR 설계
#           날짜   이름                                 작업
# 41  20220128  배소연  주간 - 6DSA5906 도면작업, 도면정리\n야근 - 없음
#           날짜   이름                           작업
# 42  20220128  한규현  주간 - Revit TRAY 설계\n야근 - 없음
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jed/Desktop/개발/App/Socket/Untitled-1.ipynb 셀 3 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a> for file_path in file_pathes:
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=40'>41</a>     try:
# ---> <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a>         df = pd.read_excel(file_path, sheet_name='일일업무')
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=42'>43</a>         date = li
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=43'>44</a>         ## 필요없는 열을 지워준다.
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/io/excel/_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1416 self.engine = engine
#    1417 self.storage_options = storage_options
# -> 1419 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:525, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     514 """
#     515 Reader using openpyxl engine.
#     516
#    (...)
#     522     passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     523 """
#     524 import_optional_dependency("openpyxl")
# --> 525 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/io/excel/_base.py:518, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     516 self.handles.handle.seek(0)
#     517 try:
# --> 518     self.book = self.load_workbook(self.handles.handle)
#     519 except Exception:
#     520     self.close()
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:536, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     533 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     534     from openpyxl import load_workbook
# --> 536     return load_workbook(
#     537         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     538     )
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/reader/excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/reader/excel.py:281, in ExcelReader.read(self)
#     279 self.read_properties()
#     280 self.read_theme()
# --> 281 apply_stylesheet(self.archive, self.wb)
#     282 self.read_worksheets()
#     283 self.parser.assign_names()
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:198, in apply_stylesheet(archive, wb)
#     195     return wb
#     197 node = fromstring(src)
# --> 198 stylesheet = Stylesheet.from_tree(node)
#     200 if stylesheet.cell_styles:
#     202     wb._borders = IndexedList(stylesheet.borders)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:103, in Stylesheet.from_tree(cls, node)
#     101 for k in attrs:
#     102     del node.attrib[k]
# --> 103 return super(Stylesheet, cls).from_tree(node)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/serialisable.py:83, in Serialisable.from_tree(cls, node)
#      79     continue
#      81 if hasattr(desc, 'from_tree'):
#      82     #descriptor manages conversion
# ---> 83     obj = desc.from_tree(el)
#      84 else:
#      85     if hasattr(desc.expected_type, "from_tree"):
#      86         #complex type
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/sequence.py:85, in NestedSequence.from_tree(self, node)
#      84 def from_tree(self, node):
# ---> 85     return [self.expected_type.from_tree(el) for el in node]
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/sequence.py:85, in <listcomp>(.0)
#      84 def from_tree(self, node):
# ---> 85     return [self.expected_type.from_tree(el) for el in node]
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/serialisable.py:87, in Serialisable.from_tree(cls, node)
#      84 else:
#      85     if hasattr(desc.expected_type, "from_tree"):
#      86         #complex type
# ---> 87         obj = desc.expected_type.from_tree(el)
#      88     else:
#      89         #primitive
#      90         obj = el.text
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/styles/fonts.py:109, in Font.from_tree(cls, node)
#     107 if underline is not None and underline.get('val') is None:
#     108     underline.set("val", "single")
# --> 109 return super(Font, cls).from_tree(node)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/serialisable.py:87, in Serialisable.from_tree(cls, node)
#      84 else:
#      85     if hasattr(desc.expected_type, "from_tree"):
#      86         #complex type
# ---> 87         obj = desc.expected_type.from_tree(el)
#      88     else:
#      89         #primitive
#      90         obj = el.text
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/serialisable.py:103, in Serialisable.from_tree(cls, node)
#     100     else:
#     101         attrib[tag] = obj
# --> 103 return cls(**attrib)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/styles/colors.py:93, in Color.__init__(self, rgb, indexed, auto, theme, tint, index, type)
#      91     self.auto = auto
#      92 else:
# ---> 93     self.rgb = rgb
#      94     self.type = 'rgb'
#      95 self.tint = tint
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/styles/colors.py:64, in RGB.__set__(self, instance, value)
#      62     if len(value) == 6:
#      63         value = "00" + value
# ---> 64 super(RGB, self).__set__(instance, value)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/base.py:43, in Typed.__set__(self, instance, value)
#      40     if (not self.allow_none
#      41         or (self.allow_none and value is not None)):
#      42         raise TypeError('expected ' + str(self.expected_type))
# ---> 43 super(Typed, self).__set__(instance, value)
#
# File ~/miniforge3/envs/AI/lib/python3.8/site-packages/openpyxl/descriptors/base.py:24, in Descriptor.__set__(self, instance, value)
#      23 def __set__(self, instance, value):
# ---> 24     instance.__dict__[self.name] = value
#
# KeyboardInterrupt:

# %%
import sqlite3 

"""
    Employee_DIV : (DES)IGNER, (CAD)
    Works_DIV : (ISS)ue_협의,(NEW)_설계(3차,2차 TRAY,배관 등 신규설계에 포함되는 건 다포함 이걸 0.5Day,1Day냐로 파악필요),(REV)_업데이트,(RET)ouch => REV_RET가 된다면 업데이트 CAD
    그 다음 주간에 두 가지 일을 할 때는 구분해서 TAT에 0.5로 표기/야근 0.25/야간은 0.5/기본 1
    교육, 관리, 보고, 협의 등은 모두 기타 작업(호기가 없으면 호기를 빼고 데이터베이스에 저장한다)
    작업의 경우의 수를 모두 뽑아봐야한다. 
"""
conn = sqlite3.connect('./DAILY_WORKS.db')
curs = conn.cursor()

sql_works_table = """
    CREATE TABLE IF NOT EXISTS M15_DAILY_WORKS(
    Date datetime,
    Name TEXT,
    Code TEXT,
    Employee_DIV TEXT, 
    Works_DIV TEXT,
    TAT TEXT
    );
    """

sql_del_table = """
    DROP TABLE M15_WORKS 
    """

curs.execute(sql_works_table)
conn.commit()
conn.close()

# %%
text = '일일보고_20220314.xlsx'
li = '20220314'

text[5:-5]
# Out:
# '20220314'

# %%
import re 

text = '문진영'
re.compile('[가-힣]').findall(text)
# Out:
# ['문', '진', '영']

# %%
import os 

count = 0
for i in range(1,12):
    li = os.listdir(f'/Users/jed/Downloads/일일보고/2022/{i}월')
    count += len(li)
    # for l in li:
    #     if l.endswith('xlsx') == True:
    #         print('파일임')
    #     else:
    #         print("폴더임")
count
# Out:
# 180

# %%
path = '/Users/jed/Downloads/일일보고/2022/10월/20221005/일일보고_20221005.xlsx'
path[-13:-5]
# Out:
# '20221005'

# %%
from enum import Enum

class workers(Enum):
    designer = 1
    CAD = 2
    manager = 3

dd = dict()

dd['방태훈'] = workers.manager
dd['방태훈'].value
# Out:
# 3

# %%
li=['주간-5MCDD601', 'revit', '설계\n야근-없음','re']

for i in range(len(li)):
    if li[i].find('\n야근') != -1:
        index = li[i].find('야근')
        back = li[i][index:index+2]
        li[i] = li[i][:index-1]
        li.insert(i+1, back)
        
print(li)
# Out:
# ['주간-5MCDD601', 'revit', '설계', '야근', 're']

# %%
import re 

han = """주간-5EV6F901 5F DR 도면작업  12/01 (100%),
5EV6F901 5F EXH 도면작업 12/01 (100%),
5EV40206 1F BYP 업데이트 12/01 (100%),
5EV40202 1F BYP 업데이트 12/01 (50%)
야근-없음"""

da ="""주간-도면작업 5EV6F901 5F DR  12/01 (100%),
5EV6F901 5F EXH 12/01 (100%),
업데이트 5EV40206 1F BYP 12/01 (100%),
5EV40202 1F BYP 12/01 (50%)
야근-없음"""

li = han.split(' ')
for l in range(len(li)):
    code = re.compile(f'[2-8]+\w+\w+\w+\d').findall(li[l])
    comma = re.compile(f',')
    if len(code) == 1:
        print(l)
    if len(comma) == 1:
        print(l)

"작업이 앞에 있고 호기 콤마로 이어진다. 뒤에 있다."
"호기 작업 콤마"
"호기와 작업의 관계"
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jed/Desktop/개발/App/Socket/Untitled-1.ipynb 셀 11 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a>     if len(code) == 1:
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a>         print(l)
# ---> <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a>     if len(comma) == 1:
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>         print(l)
#      <a href='vscode-notebook-cell:/Users/jed/Desktop/%EA%B0%9C%EB%B0%9C/App/Socket/Untitled-1.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a> "작업이 앞에 있고 호기 콤마로 이어진다. 뒤에 있다."
#
# TypeError: object of type 're.Pattern' has no len()

# %% [markdown]
# 설계사 일보 분석 방법 최종 22.12.3(참결병원)

# %%
import re
han = """주간-5EV6F901 5F DR 도면작업  12/01 (100%),
5EV6F901 5F EXH 도면작업 12/01 (100%),
5EV4d206 1F BYP 업데이트 12/01 (100%),
5EV40202 1F BYP 업데이트 12/01 (50%)
야근-없음"""

da ="""주간-도면작업 5EV6F901 5F DR  12/01 (100%),
5EV6F901 5F EXH 12/01 (100%),
업데이트 5EV40206 1F BYP 12/01 (100%),
5EV40202 1F BYP 12/01 (50%)
야근-설계 5EV40202"""

sel = """주간-5TCW4107, 5TCT3905 도면작업
야근-5EV50110 도면작업"""

code = re.compile('(\d{1}\w{4}\d{3})').findall(han)
mat = re.finditer('(\d{1}\w{4}\d{3})', da)

mat = re.finditer('(\d{1}\w{4}\d{3})', han)
retouch_index = re.finditer('도면', han)
update_indexes = re.finditer('업데', han)
sel_indexes = re.finditer('설계', han)
ju_index = re.search('주간', han)
ya_index = re.search('야근', han)

works = re.compile('(?<=(\d{1}\w{4}\d{3}))(.*?)(?=,)').findall(han)
works_jugan = re.compile('(주간)*(.+?)(\n)').findall(da)
works_yagan = re.compile('(야근)(.+?)(없음)').findall(han)

print(f"주간 위치: {ju_index.start()}")
print(f"야근 위치: {ya_index.start()}")

match_li = []
do_li = []
print("----작업 위치------")
dd = list(iter(retouch_index))
for i in range(len(dd)):
    do_li.append(i)
    # print(dd[i])

# for do in retouch_index:
#     print(f"도면 : {do.start()}")
# for up in update_indexes:
#     print(f"업데 {up.start()}")
# for up in sel_indexes:
#     print(f"설계 {up.start()}")
# mat 객체는 iter로 바꿔주고 리스트로 바꿔줘야 제대로된 비교가 된다. 안바꾸게 되면 반복문이 돌지 않는다. 위 객체와 같이 리스트객체로 인덱스로 접근한다. 
code_indexes = list(iter(mat))
print("----설비 위치------")
for j in range(len(dd)):
    # 작업 위치를 두개의 인덱스로 판단한다. ---호기--작업1 ---호기--작업2  일때 첫 작업일때는 작업1 보다 작을때만 가져오기 위해 
    # before와 after라는 변수로 함축하여 값을 정의한다. 그냥 바로 인덱스로 비교하면 조건이 까다롭다. 
    if j-1 < 0:
        before = 0
        after = dd[j].start()
    else:
        before = dd[j-1].start()
        after = dd[j].start()
    ## 이렇게 하면 작업과 작업 사이의 객체를 모두 가져올 수 있다. 하지만 호기가 같을 때 작업이 같을 때는 공종으로 비교한다. 
    # 공종 비교 TAT 정도만 남았다 작업이 .. 이제 어느정도 분석할 수 있게 되었다. 
    for code in code_indexes:
        if  before < code.start() and  after > code.start():
            print(f'인덱스 : {code.start()} 설비 명: {code.group()}')
            print(f'{dd[j].group()} {code.group()}') ## 1. 주간 야근 판별 , 2. 이름까지.. 3 .작업 이름 앞에 넣을때도 판단.

# index = 0
# up = 0
# ## CAD면 아래와 같이필요
# while index > -1:
#     try:
#         index = han.index('도면작업',index)
#         index += 3
#         if index != ValueError:
#             for match in match_li:
#                 if match < index:
#                     print(match)
#                     print(index)
#         up = han.index('업데이트',up)
#         up += 3
#         # print(up)
#     except:
#         break
# text = da.split(' ')
# li = []
# count = 0

# for i in range(len(text)):
#     if text[i].find('주간') != -1:
#         li.append('주간')
#     if text[i].find('야근') != -1:
#         li.append('야근')
#     if text[i].find('설계') != -1:
#         li.append('설계')
#     if text[i].find('도면작업') != -1:
#         li.append('도면작업')
#     if text[i].find('업데이트') != -1:
#         li.append('업데이트')
#     if text[i] == 'DR' or text[i] == 'BYP' or text[i] == 'EXH' or text[i] == 'MAIN' or text[i] == 'GAS' or text[i] == 'TOXIC':
#         li.append(text[i])  
#     code_index = re.compile('(\d{1}\w{4}\d{3})').findall(text[i])
#     if len(code_index) == 1:
#         li.append(code_index)

# for j in range(len(li)):
#     code = re.compile('\d{1}\w{4}\d{3}').findall(li[j][0])
# Out:
# 주간 위치: 0
# 야근 위치: 141
# ----작업 위치------
# ----설비 위치------
# 인덱스 : 3 설비 명: 5EV6F901
# 도면 5EV6F901
# 인덱스 : 38 설비 명: 5EV6F901
# 도면 5EV6F901

# %% [markdown]
# ### 순차 모드

# %%
import re
han = """주간-5EV6F901 5F DR 설계협의  12/01 (100%),
5EV6F901 5F EXH 도면작업 12/01 (100%),
5EV4d206 1F BYP 업데이트 12/01 (100%),
5EV40202 1F BYP 업데이트 12/01 (50%)
야근-5EV6F931 설계"""

da ="""주간-도면작업 5EV6F901 5F DR  12/01 (100%),
5EV6F901 5F EXH 12/01 (100%),
업데이트 5EV40206 1F BYP 12/01 (100%),
5EV40202 1F BYP 12/01 (50%)
야근 - 5EV40302"""

type_1 = """
 -  6DHFC814,6DHFC888 부대GAS,PCW,EXH 도면출도, 도면 확인(장비단Nozzle단connection type확인)
 -  없음
"""
sel = """주간-5TCW4107, 5TCT3905 도면작업
야근-5EV50110 도면작업"""

ddd= """주간-5ESP2201, 5ESP2202 이슈해결, 5ESP2202 설계
야근-없음"""

eee = """
주간 - 6DSP5409, 6DSP5410 도면작업
야근 - 6DSP5410, 6DFP5715 도면작업
"""

fff = """
주간 - 6DFP5628,6IHI4306,4307,4308 도면작업
야근 - 6IHI4309,4310,4311 도면작업
"""

aaa = """
주간-5TCW3907 이슈대응
야간-없음
"""
ccc="""
주간 - 6IPP2508 Revit 설계
야근 - 6IPP2508 Revit 설계
"""
from DBManager import DB_Manager
import pandas as pd 

df = pd.DataFrame()
db_manager = DB_Manager()
df = db_manager.read_table()
df_1 = df[df['Name']=='방태훈']
df_1['Employee_DIV']

def get_juya_indexes(jackup):
    indexes = []
    works_type = ['','']
    ju_index = re.search('주간', jackup)
    if ju_index != None:
        works_type[0]='주간'
        indexes.append(ju_index.start())
        print(f"주간 위치: {ju_index.start()}")
    yunjang_index = re.search('연장', jackup)
    if yunjang_index != None:  
        works_type[1]='연장'  
        indexes.append(yunjang_index.start())
        print(f"연장 위치: {yunjang_index.start()}")
    yagun_index = re.search('야근', jackup)
    if yagun_index != None:
        works_type[1]='야근'  
        indexes.append(yagun_index.start())
        print(f"야근 위치: {yagun_index.start()}")
    yagun_index = re.search('야간', jackup)
    if yagun_index != None:
        works_type[1]='야간'  
        indexes.append(yagun_index.start())
        print(f"야간 위치: {yagun_index.start()}")

    # type [주간,야근]:1, [주간,연장]:2, [,야근]:3, [,연장]:4, [,]:5
    if works_type[0] == '주간' and works_type[1] == '야근':
        works_type_gubun = "야근"
    elif works_type[0] == '주간' and works_type[1] == '연장':
        works_type_gubun = "연장"
    elif works_type[0] == '주간' and works_type[1] == '야간':
        works_type_gubun = "연장"
    elif works_type[0] == '' and works_type[1] == '야근': ##type_1에 주간을 넣어준다. 
        jackup = '주간'+jackup
        indexes.insert(0,0)
        works_type_gubun = "야근"
    elif works_type[0] == '' and works_type[1] == '연장':
        jackup = '주간'+jackup
        indexes.insert(0,0)
        works_type_gubun = "연장"
    elif works_type[0] == '' and works_type[1] == '': ##type_1에 주간만 넣어준다.
        jackup = '주간'+jackup
        indexes.insert(0,0)
        indexes.append(len(jackup))
        works_type_gubun = "야근" ## 야근 연장 구분이 없기 때문에 그냥 STR맨 끝까지 검색
    return indexes, works_type_gubun

## Ju = 1 / Yagun = 0.25 / Yunjang = 0.5 ##
def get_codes_indexes(jackup, juya_indexes, works_type_gubun):
    YAGUN = False
    YUNJANG = False
    ju_index = juya_indexes[0]
    if works_type_gubun == "야근":
        ya_index = juya_indexes[1]
        YAGUN = True
    elif works_type_gubun == "연장":
        ya_index = juya_indexes[1]
        YUNJANG = True
    
    data = []
    works_mat_object = []
    exception_li = [] ## 예외되는 작업 리스트들은 여기에 저장.
    code = re.compile('(\d{1}\w{4}\d{3})(.*?)').findall(jackup)
    mat = re.finditer('(\d{1}\w{4}\d{3})', jackup)

    contius_codes = re.sub("\s","",jackup)
    is_contius_codes = re.finditer(',\d{4}',contius_codes)

    code_indexes = list(iter(mat))

## 코드를 찾지 못한다면 
    if len(code_indexes) == 0:
        exception_li.append(jackup)
        print("코드를 찾지 못했습니다.")
    
    works = ['설계','TRAY','보강대','간섭','이슈','협의'] ## => 설계
    works_B = ['도면출도','도면작업'] ## 도면 정리 제외
    works_C = ['업데이트','REV'] ## => 업데이트

# 작업내용리스트를 돌면서 매칭된 re.Match object를 리스트로 가져온다. 단 두개 이상일때는 별도의 작업필요.
    for work in works:
        index = re.finditer(work,jackup)
        data.append(list(iter(index)))
    for B in works_B:
        index = re.finditer(B,jackup)
        data.append(list(iter(index)))
    for C in works_C:
        index = re.finditer(C,jackup)
        data.append(list(iter(index)))

# re.Match object이 2개 이상일때는 리스트를 1개로 분리해줘야한다.
    for i in range(len(data)):
        if len(data[i]) == 1:
            works_mat_object.append(data[i][0])
        elif len(data[i]) > 1:
            for da in range(len(data[i])):
                ## data[i]가 2개 이상일 때는 2차원 배열이기 때문에 2번째 배열을 변경해준다.
                works_mat_object.append(data[i][da])
    # 예외 처리

    for i in range(len(works_mat_object)):
        if i >0:
            if works_mat_object[i-1].start() > works_mat_object[i].start():
                temp = works_mat_object[i]
                works_mat_object[i] = works_mat_object[i-1] 
                works_mat_object[i-1] = temp 
    print(works_mat_object)
    # 주간과 야근 사이에 호기,, 작업이 되는지. 작업 되에 호기가 있는지 판단 
    # 야근 뒤에 호기와 작업이 있는가? 
    codes = []
    mats = []
    for code in code_indexes:
        codes.append(code.start())
    for mat in works_mat_object:
        mats.append(mat.start())
    codes.sort()
    mats.sort()
    ok_count = 0
    for m in range(len(mats)):
        if m-1 < 0:
            before = 0
            current = mats[m]
        else:
            before = mats[m-1]
            current = mats[m]
        for co in codes:
            if co > before and co < current and co < ya_index:
                ok_count+=1
            else:
                if co > ya_index and co > ya_index and current > co:
                    ok_count+=1
    if ok_count != len(codes):
        print("예외처리입니다.")
    # print(f"코드위치 {codes}")
    # print(f"작업위치 {mats}")
# 이 부분은 좀 더 고민을 해봐야 할 것 같다. 설계 이슈 이렇게 적힌 부분을 어떻게 설계 이슈로 가져와야 할 것인가. 설계\s 로도 OK이고 설계 이슈로도 오케이다. re객체를 수정하고 싶지만 그건 안될 것 같다.
# .. 나중에 고민
# 호기가 4개이고 작업이 3개일 때 같은 경우는 사용자에게 예외를 처리해야한다. 
        

    """
        분석 타입. 
            호기 호기 작업, 알수없음 
            호기 작업 , 호기 작업 
            작업 호기 호기 
            알수없음 알수없음 호기 등등
            작업 위치를 두개의 인덱스로 판단한다. ---호기--작업1 ---호기--작업2  일때 첫 작업일때는 작업1 보다 작을때만 가져오기 위해 
        예외 처리.
            1. 만약 호기가 before에 없다면 작업부터 다음 작업까지 검색해야한다.  <-----
            2. before와 after라는 변수로 함축하여 값을 정의한다. 그냥 바로 인덱스로 비교하면 조건이 까다롭다. 
            3. 이렇게 하면 작업과 작업 사이의 객체를 모두 가져올 수 있다. 하지만 호기가 같을 때 작업이 같을 때는 공종으로 비교한다. 
            4. 공종 비교 TAT 정도만 남았다 작업이 .. 이제 어느정도 분석할 수 있게 되었다. 
            5. 여기서 타입을 구분할 수 있을 것 같다. 코드와 작업의 관계를 파악할 수 있다. 만약 코드가 없다면도 파악가능! 
            6. 코드는 무조건 1개 이상이기 때문에 여기서 타입을 판단한다. 판단 할 때는 첫 작업과 호기의 관계 두개 이상이면 호기의 관계를 파악한다. 
            7. 코드의 갯수로 TAT를 판단 한다. (주간이면 1/호기)
    """
    # 주간에 작업한 호기갯수와 야근에 작업한 호기를 나눈다. 
    ju_count = 0
    ya_count = 0 
    for code in code_indexes:
        if ju_index < code.start() and ya_index > code.start():
            ju_count+=1
        if ya_index < code.start():
            ya_count+=1
    
    # TAT를 구한다. 
    # TAT는 주간에 한 호기갯수와 주간 TAT 1을 나누 값.
    JU_TAT = 1/ju_count
    # 야근 연장 TAT는 야간에 한 호기 갯수와 야근 0.25시간 연장 0.5(반일)을 나눈 값.
    if YAGUN == True and ya_count > 0:
        YA_TAT = 0.25/ya_count
    elif YUNJANG == True and ya_count > 0:
        YA_TAT = 0.5/ya_count
  
    # 마지막 반환리스트에 값을 하나씩 넣어준다. 야간 야근포함.
    # 주간 야근 사이 before 와 current는 작업을 구분하고, 그 작업 사이에 호기를 잡아낸다. 다음은 야근 이후의 작업을 잡아낸다. 없으면 버림. 
    final_list = []
    for j in range(len(works_mat_object)):
        if j-1 < 0: 
            before = 0
            current = works_mat_object[j].start()
        elif works_mat_object[j].start() > ya_index:
            before = ya_index
            current = works_mat_object[j].start()
        else:
            before = works_mat_object[j-1].start()
            current = works_mat_object[j].start()
            # print(before,current)
        # 주간 작업
        text_judo = []
        for code in code_indexes:
            # print(before," ", code.start()," ", current)
            if code.start() > before and code.start() < current and code.start() < ya_index:
                # print(f'인덱스 : {code.start()} 설비 명: {code.group()}')
                final_list.append("주간")
                final_list.append(works_mat_object[j].group())
                final_list.append(code.group())
                text_judo.append(code.group())
                final_list.append(JU_TAT)
                # print(f'주간 작업 : {works_mat_object[j].group()} 호기 : {code.group()} TAT :{tat}')
        # 야간 작업
        for code in code_indexes:
                # print(before," ", code.start()," ", current)
            if code.start() > before and code.start() < current and code.start() > ya_index:
                # print(f'인덱스 : {code.start()} 설비 명: {code.group()}')
                if YAGUN == True:
                    final_list.append("야근")
                elif YUNJANG == True:
                    final_list.append("연장")
                final_list.append(works_mat_object[j].group())
                final_list.append(code.group())
                text_judo.append(code.group())
                final_list.append(YA_TAT)
    # if len(code_indexes) - len(text_judo)/4 > 0:
    #     for code in code_indexes:
    #         for li in text_judo:
    #             if li != code.group():
    #                 print(code.group())
    return final_list

dd , d = get_juya_indexes(ccc)
fili = get_codes_indexes(ccc, dd, d)
print(fili)
# 도면작업, 업데이트, REV, 설계, REV+설계 = REV, TRAY도 설계로 , 보강대 간섭확인 도 설계로 , 설계이슈 -> 설계
# works = re.compile('(?<=(\d{1}\w{3}\d{4}))(.*?)(?=,)').findall(mat)
# works_jugan = re.compile('(주간)*(.+?)(\n)').findall(type_1)
# works_yagun = re.compile('(야근)(.+?)(없음)').findall(type_1)
# works_yagan = re.compile('(야간)(.+?)(없음)').findall(type_1)
# Out:
# 10                         주간-5TCW4107 설계\n야근-5TCW4107 설계
# 43                         주간-5TCW4107 설계\n야근-5TCW4108 설계
# 76         주간-5TCT3905 현장미팅, 5TCW3907, 5TCW3908 설계\n야근-없음
# 108                              주간-M16미팅\n야근-5TCW4108 설계
# 140                               주간-5TCW4107 현장대응\n야근-없음
# 172                          주간-5TCW4115 이슈협의 현장대응\n야근-없음
# 204                          주간-5TCW4108 이슈협의\n야근-이슈 현장대응
# 236                주간-5TCW4115 현장대응\n야근-5TCW4115 이슈협의, 설계
# 267                      주간-5TCW4106 이슈대응\n야근-5TCW4106 설계
# 298                  주간-5EV45901 설계, 이슈대응\n야근-5EV45901 설계
# 329                                 주간-5EV45901 설계\n야근-없음
# 360                        주간-5EV45901 설계\n야근-5EV45901 설계
# 391                                                    연차
# 422                                                    연차
# 453                                                    연차
# 486                                 주간-5EV45901 설계\n야근-없음
# 519                        주간-5EV45901 설계\n야근-5TCW4115 설계
# 553                주간-5TCW4115 이슈대응, 5TCW4108 이슈대응\n야근-없음
# 587         주간-5TCW4115 검토, 5TCW4108 REV\n야근-5EHS2801 REV
# 621                      주간-5EV40108, 5EV45901 REV\n야근-없음
# 655                                 주간-5TCW3805 설계\n야근-없음
# 687                        주간-5EV50107 설계\n야근-5EV60101 설계
# 719                           주간-5EV60101 설계, 이슈대응\n야근-없음
# 751                     주간-5EV60101 설계, 이슈대응\n야근-5EV60401
# 783                           주간-5EV60101 설계, 이슈대응\n야근-없음
# 815                           주간-5EV60401 설계, 이슈대응\n야근-없음
# 846                                      주간-현장이슈대응\n야근-없음
# 877                  주간-신입면접, 5PPW4401 설계\n야근-5PPW4401 설계
# 908                       주간-5PCD4401, 5PCD4406 설계\n야근-없음
# 939                             주간-면접, 5PCD4406 설계\n야근-없음
# 970                         주간-현장이슈대응, 5TCW3805 설계\n야근-없음
# 1000                              주간-현장이슈대응, 정합성작업\n야근-없음
# 1030                        주간-현장이슈대응, 5PCD4401 설계\n야근-없음
# 1060                      주간-5PCD4401, 5TCW3805 설계\n야근-없음
# 1090                      주간-5TCW3805, 5TCW4115 설계\n야근-없음
# 1120                       주간-5TCW4115 설계\n야근-5TCW4115 설계
# 1152                       주간-5TCW4115 설계\n야근-5TCW4115 설계
# 1184                                주간-5TCW4115 설계\n야근-없음
# 1216                       주간-5TCW4115 설계, 설계 이슈대응\n야근-없음
# 1248             주간-5TCW4115, 5TCW3805 설계, 설계 이슈대응\n야근-없음
# 1280    주간-5TCW4115, 5TCW3805 설계, 설계 이슈대응\n야근-5TCW3805 설계
# 1312             주간-5TCW4115, 5TCW3805 설계, 설계 이슈대응\n야근-없음
# 1344             주간-5TCW4115, 5TCW3805 설계, 설계 이슈대응\n야근-없음
# 1376              주간-5TCW3805,5CMI5501 설계, 설계 이슈대응\n야근-없음
# 1408                       주간-5TCW3805 설계, 설계 이슈대응\n야근-없음
# 1440                 주간-5TCW3805 설계, 이슈대응\n야근-5PEB4402 설계
# 1473                주간-5PEB4402, 5TCW3805 설계, 이슈대응\n야근-없음
# 1505                주간-5TCW4115, 5TCW3805 설계, 이슈대응\n야근-없음
# 1537        주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-없음
# 1569        주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-없음
# 1601    주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-5TC...
# 1632        주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-없음
# 1663    주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-5TC...
# 1694    주간-5TCW4115, 5TCW3805 설계, 정보추출교육, 이슈대응\n야근-5TC...
# 1724                  주간-5TCW3805 설계, 정보추출교육, 이슈대응\n야근-없음
# 1756                  주간-5TCW3805 설계, 정보추출교육, 이슈대응\n야근-없음
# 1788                          주간-5TCW3805 설계, 이슈대응\n야근-없음
# 1820                 주간-5TCW3805 설계, 이슈대응\n야근-5TCW3805 설계
# 1852                          주간-5TCW3805 설계, 이슈대응\n야근-없음
# 1884                 주간-5TCW3805 설계, 이슈대응\n야근-5TCW3805 설계
# 1916                 주간-5TCW3805 설계, 이슈대응\n야근-5TCW3806 설계
# 1948                         주간-신입면접, 5TCW4115 REV\n야근-없음
# 1979                                주간-5TCW3806 설계\n야근-없음
# 2010                                주간-5TCW3806 설계\n야근-없음
# 2041                                주간-5TCW3806 설계\n야근-없음
# 2073                       주간-5TCW3808 설계\n야근-5TCW3808 설계
# 2105                                주간-5TCW3808 설계\n야근-없음
# 2137                       주간-5TCW3808 설계\n야근-5TCW3808 설계
# 2169             주간-5TCW3808, 5TCW4115 설계\n야근-5TCW3808 설계
# 2201            주간-5TCW3808 설계, 5TCW4115 REV\n야근-5TCW3808
# 2233                            주간-5TCW3808, VMB설계\n야근-없음
# 2267                            주간-5TCW3808, VMB설계\n야근-없음
# 2300                              주간-본사방문\n야근-5TCW3808 설계
# 2334                                주간-5TCW3808 설계\n야근-없음
# 2367                                주간-5TCW3808 설계\n야근-없음
# 2400           주간-5EPL2601 설계, 이슈협의, 설계교육\n야근-5EPL2601 설계
# 2433                                주간-5EPL2601 설계\n야근-없음
# 2466                          주간-5EPL2601 설계, 이슈협의\n야근-없음
# 2499                        주간-5TCW3806 업데이트, 이슈협의\n야근-없음
# 2532             주간-5TCW3806 업데이트, 이슈협의\n야근-5TCW3806 업데이트
# 2565                        주간-5TCW3806 업데이트, 이슈협의\n야근-없음
# 2598                                                   연차
# 2631                       주간-5TCW3806 업데이트, 현장확인\n야근-없음
# 2664                              주간-5TCW3806 업데이트\n야근-없음
# 2697                              주간-5TCW3808 업데이트\n야근-없음
# 2727                              주간-5TCW3808 업데이트\n야근-없음
# 2758                       주간-5TCW4004 설계\n야근-5TCW4004 설계
# 2789                 주간-5TCW4004 설계, 이슈처리\n야근-5TCW4004 설계
# 2820                            주간-5TCW4004설계 이슈대응\n야근-없음
# 2854                           주간-5TCW4004설계, 이슈대응\n야근-없음
# 2888                           주간-5TCW4003설계, 이슈대응\n야근-없음
# 2922                   주간-5TCW3805 업데이트\n야근-5TCW3805 업데이트
# 2956                     주간-5TCW3805 업데이트\n야근-5TCW4003 설계
# 2990                                주간-5TCW4003 설계\n야근-없음
# 3024                       주간-5TCW4003 설계\n야근-5TCW4003 설계
# 3058                       주간-5TCW4003 설계\n야근-5TCW4003 설계
# 3092                       주간-5TCW4003 설계\n야근-5TCW4003 설계
# 3126                       주간-5TCW4003 설계\n야근-5TCW4003 설계
# 3160                                주간-5TCW4003 설계\n야근-없음
# 3194             주간-5TCW4003, 5TCW3907 설계\n야근-5TCW3907 설계
# 3227                       주간-5TCW3907 설계\n야근-5TCW3907 설계
# 3260                                주간-5TCW3907 설계\n야근-없음
# 3292                                주간-5TCW3907 설계\n야근-없음
# 3324                              주간-5TCW3905 업데이트\n야근-없음
# 3356                        주간-5TCW3808 업데이트, 현장대응\n야근-없음
# 3391                     주간-5TCW4004 업데이트, 정보추출 작업\n야근-없음
# 3424                        주간-5EHS2905 설계, 현장이슈대응\n야근-없음
# 3457              주간-5TCW4004, 5TCW4003 설계, 현장이슈대응\n야근-없음
# 3490                              주간-5TCW3907 이슈대응\n야간-없음
# 3523                        주간-5TCW4004 업데이트, 현장대응\n야간-없음
# 3557                                   주간-REVIT 교육\n야간-없음
# 3590                      주간-5TCW4004 업데이트, 현장이슈대응\n야간-없음
# 3623                      주간-5TCW4004 업데이트, 현장이슈대응\n야간-없음
# 3655                              주간-VMB설계, 현장이슈대응\n야간-없음
# 3687                      주간-5TCW3907 업데이트, 현장이슈대응\n야간-없음
# 3719                                       하계휴가(8/8~8/12)
# 3751                                       하계휴가(8/8~8/12)
# 3783                                       하계휴가(8/8~8/12)
# 3815                                       하계휴가(8/8~8/12)
# 3847                   주간-5TCW3907 업데이트\n야간-5TCW3907 업데이트
# 3879             주간-5TCW3907 업데이트\n야간-5TCW3907 업데이트, PC세팅
# 3911                         주간-5TCW3907 업데이트\n야간-PC반입 세팅
# 3943      코로나19 확진(2022.08.19~2022.08.25, 출근일: 2022.8.26)
# 3975      코로나19 확진(2022.08.19~2022.08.25, 출근일: 2022.8.26)
# 4007      코로나19 확진(2022.08.19~2022.08.25, 출근일: 2022.8.26)
# 4039      코로나19 확진(2022.08.19~2022.08.25, 출근일: 2022.8.26)
# 4071      코로나19 확진(2022.08.19~2022.08.25, 출근일: 2022.8.26)
# 4103                             주간-이슈정리, revit 교육\n야간-없음
# 4135                       주간-이슈정리, revit 교육\n야근-revit 교육
# 4167                                  주간-BIM데이터 체크\n야근-없음
# 4198           주간-5EV4G011 revit 설계\n야근-5EV4G011 revit 설계
# 4228                          주간-5EV4G011 revit 설계\n야근-없음
# 4259     주간-5EV4G011 revit 설계, 이슈관리\n야근-5EV4G011 revit 설계
# 4290                                                   연차
# 4321                    주간-5EV4G011 revit 설계, 이슈관리\n야근-없음
# 4352              주간-5EV4G011 revit 설계, 설계교육\n야근-정산분 캡처작업
# 4383                    주간-5ELEF801 revit 설계, 설계교육\n야근-없음
# 4414                           주간-이슈확인, BIM DATA확인\n야근-없음
# 4445                        주간-BIM DATA 확인, 직관확인\n야근-직관확인
# 4476                                     주간-증설라인수정\n야근-없음
# 4507                    주간-5ELEF801 revit 설계, 이슈확인\n야근-없음
# 4538                    주간-5ELEF801 revit 설계, 이슈확인\n야근-없음
# 4568     주간-5ELEF801 revit 설계, 이슈확인\n야근-5ELEF801 revit 설계
# 4598    주간-5ELEF801 revit 설계, TRAY 확인\n야근-5ELEF801 rev...
# 4628           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4658                          주간-5ELEF801 revit 설계\n야근-없음
# 4688           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4718           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4748           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4778                          주간-5ELEF801 revit 설계\n야근-없음
# 4808           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4838           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4868           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4898           주간-5ELEF801 revit 설계\n야근-5ELEF801 revit 설계
# 4928                    주간-5ELEF801 revit 설계, 이슈대응\n야근-없음
# 4958                              주간-5ELEF801 이슈대응\n야근-없음
# 4988          주간-5ELEF801 Rev, 이슈대응\n야근-5EV4G011 revit 설계
# 5018                 주간-이슈대응, 5EV4G011 설계\n야근-5EV4G011 설계
# 5048                주간-5ELEF801 rev, 이슈대응\n야근-5EV4G011 설계
# 5075                          주간-5EV4G011 설계, 이슈대응\n야근-없음
# 5102                             주간-2,3차 TRAY 이슈대응\n야근-없음
# 5129    주간-5ELEF801 이슈협의, ETCH BAY 한양구역 2차 TRAY 협의, 현장...
# 5156    주간-5ELEF801 현장미팅, TRAY간섭 협의, 5ELEF801 rev 11/1...
# 5182    주간-설계교육, 5TCT4002 이슈대응, 5EV4G011 설계 11/14 시작(5...
# 5208    주간-비상대피훈련, 설계교육, 이슈대응,\n5ELEF801 rev 11/16시작(1...
# 5234    주간 - 설계교육, 이슈자료준비 및 대응\n         5ELEF801 rev ...
# 5260     주간-설계교육, 이슈대응,\n5EV4G011 설계 11/14 설계(65%)\n야근-없음
# 5286    주간-설계교육, 이슈대응,\n5EV4G011 설계 11/14 (70%), 2차 TR...
# 5312    주간 - 이슈대응,\n         5EV4G011 설계 11/14 (70%), ...
# 5338    주간-이슈대응, 2차 TRAY 협의\n5EV4G011 설계 11/14 (80%)\n...
# 5364            주간-이슈대응,\n5EV4G011 설계 11/14 (100%)\n야근-없음
# Name: Employee_DIV, dtype: object
# 주간 위치: 1
# 야근 위치: 24
# [<re.Match object; span=(21, 23), match='설계'>, <re.Match object; span=(44, 46), match='설계'>]
# ['주간', '설계', '6IPP2508', 1.0, '야근', '설계', '6IPP2508', 0.25]

# %% [markdown]
# ### 연속 숫자 모드

# %% [markdown]
# ### 사용자별 작업내용 엑셀에 담기담기
# 12.9 6시 30부터...4시가 넘어가게 이것까지 만들고 있다.

# %%
from DBManager import DB_Manager
import pandas as pd 
import Works_Analsis as wa
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # Cell의 모든 반환값 출력


pd.options.display.max_rows = 10000

columns = ['Date','Name','Gubun','WORK','CODE','TAT','Error']

name = '권동현'

df = pd.DataFrame()
insa = pd.DataFrame(columns=columns)
db_manager = DB_Manager()
df = db_manager.read_table()
df_1 = df[df['Name']==name]

i=0
for row in df_1.iterrows():
    works = row[1]['Employee_DIV']
    dd , d = wa.get_juya_indexes(works)
    li = wa.get_codes_indexes(works, dd, d)
    
    if type(li) == list:
        if len(li) > 4:
            new_li = []
            for j in range(0,int(len(li)/4)):
                new_li = li[j*4:(j*4)+4]
                new_li.insert(0, row[1]['Date'])
                new_li.insert(1, row[1]['Name'])
                new_li.insert(6, "")
                insa.loc[i+j] = new_li
            i+=len(li)/4 # 야근이 있으면 두 칸씩 써지기 때문에 2개씩 만약 12개면 3개로 해야한다.
        elif len(li) == 4:
            li.insert(0, row[1]['Date'])
            li.insert(1, row[1]['Name'])
            li.insert(6, "")
            insa.loc[i] = li
            i+=1
        else:
            li.insert(0, row[1]['Date'])
            li.insert(1, row[1]['Name'])
            li.insert(2, "")
            li.insert(3, "")
            li.insert(4, "")
            li.insert(5, "")
            li.insert(6, li)
            # insa.loc[i] = li
            i+=1

        if type(li) == int:
            li.insert(0, row[1]['Date'])
            li.insert(1, row[1]['Name'])
            li.insert(2, "")
            li.insert(3, "")
            li.insert(4, "")
            li.insert(5, "")
            li.insert(6, li)
            insa.loc[i] = li
            i+=1
        # if len(li) > 4:
        #     new_li = []
        #     for j in range(len(li)):
        #         if j % 4 == 0:
                    
insa.to_excel(f'{name}.xlsx')
    # if type(li) == 'list':
    #     print(li)
    # if type(li) == 'int':
    #     print(li)
# Out:
# 코드를 찾지 못했습니다 :  주간-업무프로세서 및 5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-업무프로세서 및 5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-업무프로세서 및 5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-업무프로세서 및 5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-업무프로세서 및 5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육, 업데이트 도면정리
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육, 업데이트 도면정리
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육, CAD Retouch 교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5D교육, CAD Retouch 교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-CAD Retouch 교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-CAD Retouch 교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-TRAY 업데이트
# 야근-TRAY 업데이트
# 코드를 찾지 못했습니다 :  주간-TRAY 업데이트, E36SiCl4-c01 도면작업
# 야근-TRAY 업데이트
# 코드를 찾지 못했습니다 :  주간-E36SF6-0130 설계
# 야근-없음
# 코드를 찾지 못했습니다 :  경조휴가(조부상)
# 코드를 찾지 못했습니다 :  주간-VMB설계
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-VMB설계
# 야근-없음
# 코드를 찾지 못했습니다 :  휴가
# 코드를 찾지 못했습니다 :  휴가
# 코드를 찾지 못했습니다 :  주간-정보추출, REVIT교육
# 야근-REVIT 교육
# 코드를 찾지 못했습니다 :  주간-E40CHF3-1004, E39CL2-1201 업데이트
# 야근-E39NF3-0311, 0312 업데이트
# 코드를 찾지 못했습니다 :  주간-E39NF3-0311,0312 업데이트, 정보추출
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-E39Cl20-1201, E38Cl2-12 업데이트
# 야근-E39Cl2-12 업데이트, revit 교육
# 코드를 찾지 못했습니다 :  주간-revit 교육, 정산캡처작업
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-5ESP export, revit 교육
# 야근-revit 교육
# 코드를 찾지 못했습니다 :  연차
# 코드를 찾지 못했습니다 :  주간-revit 교육
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-revit 교육, 정산분 캡처작업
# 야근-정산업무
# 코드를 찾지 못했습니다 :  주간-정산업무, 정보추출작업
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-직관도면작업
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-GN2 라인증설
# 야근-없음
# 예외처리입니다 :  주간-5MCDD401 rev 11/11시작(60%)
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-코로나 자가격리(휴가)
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-코로나 자가격리(휴가)
# 야근-없음
# 코드를 찾지 못했습니다 :  주간-코로나 자가격리(휴가)
# 야근-없음
# 코드를 찾지 못했습니다 :  주간 - 코로나 자가격리(휴가)
# 연장  -없음
# 코드를 찾지 못했습니다 :  주간-코로나 자가격리(휴가)
# 야근-없음
